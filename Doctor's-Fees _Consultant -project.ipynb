# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_excel('Final_Train.xlsx')

# %%
ds.to_csv('Final_Train.csv')

# %%
ds
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
ds1=pd.read_excel('Final_Test.xlsx')

# %%
ds1.to_csv('Final_Test.csv')

# %%
ds1
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %% [markdown]
# Till here we have imported the dataset into the pandas dataframe.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (5961, 7)

# %% [markdown]
# Here we can see that we have 5961 rows and 7 columns.

# %%
df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# ...

# %%
df.Fees.unique()
# Out:
# array([100, 350, 300, 250, 200, 700, 500, 400, 150, 650, 600,  50, 800,
#        750, 450,  80,  60, 550, 900, 950, 430, 130, 630, 499, 260,  70,
#         10, 299, 230, 380,   5, 280,  40,  30, 180, 920, 125, 850,  20,
#        220], dtype=int64)

# %%
df.Fees.value_counts()
# Out:
# 100    1306
# 500     938
# 200     904
# 300     864
# 400     424
# 250     307
# 150     253
# 600     215
# 700     153
# 800     143
# 350     143
# 50       81
# 450      65
# 750      34
# 550      22
# 650      21
# 900      18
# 70       18
# 80       12
# 60       11
# 30        4
# 10        2
# 260       2
# 130       2
# 180       2
# 40        2
# 380       2
# 220       1
# 280       1
# 499       1
# 5         1
# 920       1
# 299       1
# 125       1
# 230       1
# 430       1
# 630       1
# 850       1
# 950       1
# 20        1
# Name: Fees, dtype: int64

# %% [raw]
# We can see that Fees column is our dependent variable and is continous in nature,thus it is a linear Regression problem.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# To check missing values

# %%
df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %% [markdown]
# we can see that we have null values in our dataset.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# THe light shades lines are showing the null values present in our dataset.

# %% [raw]
# We can see that our whole dataset is in string format except fees column.So for further analysis we have to use label encoding to change it to integer format.

# %% [markdown]
# # Label Encoding

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['Qualification']=le.fit_transform(df['Qualification'])

# %%
df['Experience']=le.fit_transform(df['Experience'])

# %%
df['Rating']=le.fit_transform(df['Rating'])

# %%
df['Profile']=le.fit_transform(df['Profile'])

# %%
df['Place']=le.fit_transform(df['Place'])

# %%
df['Miscellaneous_Info']=le.fit_transform(df['Miscellaneous_Info'])

# %% [markdown]
# WE have encoded all the columns Let's check

# %%
df.head()
# Out:
#    Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  Fees
# 0            401          16       0    299        5                 130   100
# 1             73           3      49    866        0                1422   350
# 2           1135          63      51    457        3                2998   300
# 3            464           3      51     68        0                1695   250
# 4             10          12       0    337        0                 253   250

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#        Qualification   Experience       Rating        Place      Profile  \
# count    5961.000000  5961.000000  5961.000000  5961.000000  5961.000000
# mean      596.857574    23.010904    42.784768   417.089918     2.441872
# std       413.842446    20.937163    16.378538   259.983793     1.658014
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       219.000000     6.000000    46.000000   197.000000     1.000000
# 50%       596.000000    15.000000    51.000000   412.000000     2.000000
# 75%       943.000000    36.000000    51.000000   632.000000     4.000000
# max      1419.000000    63.000000    51.000000   877.000000     5.000000
#
#        Miscellaneous_Info         Fees
# count         5961.000000  5961.000000
# mean          2189.995471   307.944640
# std            960.101243   190.920373
# min              0.000000     5.000000
# 25%           1477.000000   150.000000
# 50%           2703.000000   300.000000
# ...

# %% [raw]
# key observations:
#
# 1 The difference in mean and median is almost similar.
#
# 2 There ia large difference in 75% percentile and max column in many columns     like  place and fees , which shows that many   outliers are present in it.
#
# 3 The columns like rating and miscellaneous_info has no difference in 75%          percentile and and max column shows that there are no outliers .

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# So we are using  boxplot

# %%
df['Qualification'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers

# %%
df['Experience'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers

# %%
df['Rating'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that extreme outliers are present and null values are also present.

# %%
df['Place'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers

# %%
df['Profile'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Also in this column we can see that we have no outliers.

# %%
df['Miscellaneous_Info'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here in this column alos we have no outliers.

# %%
df['Fees'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here alos we have no outliers in this column.

# %% [markdown]
# From the above plots we have seen the outliers present in out dataset.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Now we are plotting scatter plotsto see the relation of each column with target column

# %%
plt.scatter(df['Qualification'],df['Fees'])
plt.show()

# %% [markdown]
# here  we can see that we have no linear relation in both the columns sometimes fees increses or sometimes fees decreses.

# %%
plt.scatter(df['Experience'],df['Fees'])
plt.show()

# %% [markdown]
# Here also we can see that we have no linear relation in both the columns sometimes fees increses or sometimes fees decreses.

# %%
plt.scatter(df['Rating'],df['Fees'])
plt.show()

# %% [markdown]
# Here in this column we can see fees increses and decreases gradually with the ratings.

# %%
plt.scatter(df['Profile'],df['Fees'])
plt.show()

# %% [markdown]
# Here in this column we can see that fees increses and decreases both .

# %%
plt.scatter(df['Miscellaneous_Info'],df['Fees'])
plt.show()

# %% [markdown]
# Here also we can see that we have no linear relation in both the columns sometimes fees increses or sometimes fees decreses.

# %% [raw]
# From the above plots we have seen the relation of each column with the target column.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# To check correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                     Qualification  Experience    Rating     Place   Profile  \
# Qualification            1.000000    0.003325  0.006554  0.006321  0.393123
# Experience               0.003325    1.000000 -0.030392 -0.009908 -0.032711
# Rating                   0.006554   -0.030392  1.000000  0.024444  0.046574
# Place                    0.006321   -0.009908  0.024444  1.000000  0.016631
# Profile                  0.393123   -0.032711  0.046574  0.016631  1.000000
# Miscellaneous_Info      -0.102458    0.042818  0.497767  0.050038  0.020069
# Fees                     0.263214   -0.048529 -0.071205 -0.063510  0.145226
#
#                     Miscellaneous_Info      Fees
# Qualification                -0.102458  0.263214
# Experience                    0.042818 -0.048529
# Rating                        0.497767 -0.071205
# Place                         0.050038 -0.063510
# Profile                       0.020069  0.145226
# Miscellaneous_Info            1.000000 -0.162693
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that light shades are highly correlated.

# %%
plt.figure(figsize=(8,4))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# Observations:
#
# Dark shades are highly negatively correlated.
#
# Here we can see that most of the column like rating, miscellaneous_info are highly negatively correlated  with  fees column
#
# Experience and place columns are also negatively correlated.
#
# Qualification column is slightly positively correlated with the target column.

# %%
# another example of multivariate analysis
sns.pairplot(df)

# %% [markdown]
# From the above pairplot we can see the relation of each column with the other columns.

# %% [markdown]
# # To check skewness

# %%
sns.distplot(df['Qualification'])
# Out:
# <AxesSubplot:xlabel='Qualification', ylabel='Density'>

# %% [markdown]
# Here we can see that skewness is present in our data.

# %%
sns.distplot(df['Experience'])
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Density'>

# %% [markdown]
# here we can see that the curve is not normally ditributed.

# %%
sns.distplot(df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %% [markdown]
# Here we can see that both the curves are not normally distributed.

# %%
sns.distplot(df['Place'])
# Out:
# <AxesSubplot:xlabel='Place', ylabel='Density'>

# %% [markdown]
# Here we can see the skewness in all the curves.

# %%
sns.distplot(df['Profile'])
# Out:
# <AxesSubplot:xlabel='Profile', ylabel='Density'>

# %% [markdown]
# Here  in this column also  we can see the skewness.

# %%
sns.distplot(df['Miscellaneous_Info'])
# Out:
# <AxesSubplot:xlabel='Miscellaneous_Info', ylabel='Density'>

# %% [markdown]
# Here in this plot  we can see that the curve is skewwed  from the right side.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Removing the null values

# %%
df['Place'].fillna(df['Place'].median(),inplace=True)

# %%
df['Rating'].fillna(df['Rating'].median(),inplace=True)

# %%
df['Miscellaneous_Info'].fillna(df['Miscellaneous_Info'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Qualification         0
# Experience            0
# Rating                0
# Place                 0
# Profile               0
# Miscellaneous_Info    0
# Fees                  0
# dtype: int64

# %% [markdown]
# Here we can see that we have removed all the null values from the dataset

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[4.73305738e-01, 3.34882629e-01, 2.61246491e+00, ...,
#         1.54301587e+00, 2.14578233e+00, 1.08926083e+00],
#        [1.26594438e+00, 9.55840219e-01, 3.79506009e-01, ...,
#         1.47289258e+00, 7.99978026e-01, 2.20295441e-01],
#        [1.30046489e+00, 1.91011789e+00, 5.01627271e-01, ...,
#         3.36652489e-01, 8.41653230e-01, 4.16158134e-02],
#        ...,
#        [2.07239780e-03, 5.72670771e-01, 3.18445378e-01, ...,
#         9.39834180e-01, 1.05934743e+00, 1.52985171e+00],
#        [8.36481290e-01, 8.12542314e-01, 1.08979039e-01, ...,
#         9.39834180e-01, 1.25044484e-02, 1.08926083e+00],
#        [8.55125573e-01, 7.17010377e-01, 2.61246491e+00, ...,
#         8.69710893e-01, 6.19773580e-01, 5.65438323e-01]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 275,  293,  987, 1314, 1631, 2165, 2252, 2393, 2428, 2522, 2623,
#        2708, 3365, 4040, 4581, 4730, 4835, 5195, 5250, 5311], dtype=int64), array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6],
#       dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0               401          16       0    299        5                 130
# 1                73           3      49    866        0                1422
# 2              1135          63      51    457        3                2998
# 3               464           3      51     68        0                1695
# 4                10          12       0    337        0                 253
# ...             ...         ...     ...    ...      ...                 ...
# 5956           1075          10      49     70        3                1385
# 5957            596          26      51    541        4                2998
# 5958            596          35      48    216        4                1173
# 5959            943           6      41    850        4                2202
# 5960            243           8       0    603        1                1595
#
#       Fees
# 0      100
# 1      350
# 2      300
# ...

# %%
df.shape
# Out:
# (5961, 7)

# %%
df_new.shape
# Out:
# (5941, 7)

# %% [markdown]
# Here we can see that 20 rows are deleted as outliers .

# %% [markdown]
# Removing Skewness

# %% [markdown]
# # Separating independent variable and target variable.

# %%
x1=df_new.drop('Fees',axis=1)
y1=df_new['Fees']

# %%
x1.skew()
# Out:
# Qualification         0.242035
# Experience            0.825063
# Rating               -2.053463
# Place                 0.117122
# Profile               0.111080
# Miscellaneous_Info   -0.821519
# dtype: float64

# %% [markdown]
# Here we can see the skewness in 3 columns.

# %%
x1['Experience']=np.sqrt(x1['Experience'])
sns.histplot(x1['Experience'])
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Count'>

# %%
x1['Rating']=np.cbrt(x1['Rating'])
sns.histplot(x1['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
x1['Miscellaneous_Info']=np.cbrt(x1['Miscellaneous_Info'])

# %%
x1.skew()
# Out:
# Qualification         0.242035
# Experience            0.280415
# Rating               -2.332196
# Place                 0.117122
# Profile               0.111080
# Miscellaneous_Info   -2.299419
# dtype: float64

# %% [markdown]
# Now we can see that skewness is removed from all the columns.

# %% [markdown]
# # Creating Train test split

# %%
x=x1
x.shape
# Out:
# (5941, 6)

# %%
y=y1
y.shape
# Out:
# (5941,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (5941, 1)

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=45)

# %%
x_train.shape
# Out:
# (4158, 6)

# %%
x_test.shape
# Out:
# (1783, 6)

# %%
y_train.shape
# Out:
# (4158, 1)

# %%
y_test.shape
# Out:
# (1783, 1)

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # Finding Best Algorithm using multiple models.

# %%
lm=LinearRegression()
dtr=DecisionTreeRegressor()
svr=SVR()
knr=KNeighborsRegressor()
ls=Lasso(alpha=0.0001)
rd=Ridge(alpha=0.0001)

# %%
model=[lm,dtr,svr,knr,ls,rd]

for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('error:',m)
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Mean squared error:',mean_squared_error(y_test,pred))
    print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error: LinearRegression()
# Mean absolute error: 145.0245083542257
# Mean squared error: 31704.870644362596
# Root Mean Squared error: 178.0586157543706
# error: DecisionTreeRegressor()
# Mean absolute error: 172.82950084127873
# Mean squared error: 54368.26977005048
# Root Mean Squared error: 233.17004475285944
# error: SVR()
# Mean absolute error: 141.16836080273723
# Mean squared error: 32441.851782160764
# Root Mean Squared error: 180.11621743241435
# error: KNeighborsRegressor()
# Mean absolute error: 145.2888390353337
# Mean squared error: 35064.7331912507
# Root Mean Squared error: 187.25579614861243
# error: Lasso(alpha=0.0001)
# Mean absolute error: 145.02450232080244
# Mean squared error: 31704.850523804038
# Root Mean Squared error: 178.05855925454424
# error: Ridge(alpha=0.0001)
# Mean absolute error: 145.02450823080667
# Mean squared error: 31704.870112231438
# Root Mean Squared error: 178.05861426011222

# %% [markdown]
# We are getting minimum error with Linear Regression

# %%
# Let's check  the r2_score for the models

# %%
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('score:',m)
    print(r2_score(y_test,pred))
# Out:
# score: LinearRegression()
# 0.07176715487926333
# score: DecisionTreeRegressor()
# -0.6009860925581132
# score: SVR()
# 0.05019034083033591
# score: KNeighborsRegressor()
# -0.02660053146444641
# score: Lasso(alpha=0.0001)
# 0.07176774395478824
# score: Ridge(alpha=0.0001)
# 0.07176717045862413

# %% [markdown]
# We are getting maximum r2_score with Linear regression

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('score:',m)
    print(score)
    print(score.mean())
# Out:
# score: LinearRegression()
# [0.0790121  0.08177881 0.09189517 0.08104041 0.0957436 ]
# 0.08589401548502587
# score: DecisionTreeRegressor()
# [-0.63169393 -0.50336687 -0.57454135 -0.64050968 -0.55924104]
# -0.5818705741969538
# score: SVR()
# [0.05626898 0.03358457 0.05954094 0.03390195 0.06272873]
# 0.04920503322270724
# score: KNeighborsRegressor()
# [-0.04677698 -0.01707484  0.06411957  0.01196707  0.05292123]
# 0.013031209849925118
# score: Lasso(alpha=0.0001)
# [0.07901213 0.08177877 0.09189504 0.08104077 0.09574345]
# 0.08589403144101256
# score: Ridge(alpha=0.0001)
# [0.0790121  0.08177881 0.09189516 0.08104041 0.0957436 ]
# 0.08589401561920282

# %% [markdown]
# We are geting least diference in SVR model so this is our best model

# %% [markdown]
# # Hyper parameter tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
dtr=DecisionTreeRegressor()
grid_param={'criterion':['mse','mae','friedman_mse','poisson']}
gd_sr=GridSearchCV(estimator=dtr,
                   scoring='accuracy',
                   param_grid=grid_param,
                   cv=5)
gd_sr.fit(x_train,y_train)
best_parameters=gd_sr.best_params_
print(best_parameters)
# Out:
# {'criterion': 'mse'}

# %%
dtr=DecisionTreeRegressor(criterion='mse')
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 0.9988183318601968

# %%
param={'n_neighbors':np.arange(1,12,2),
      'weights':['uniform','distance']}
knr=KNeighborsRegressor()
gscv=GridSearchCV(knr,param,cv=5)
gscv.fit(x_train,y_train)

best_parameters=gscv.best_params_
print(best_parameters)
# Out:
# {'n_neighbors': 11, 'weights': 'distance'}

# %%
knr=KNeighborsRegressor(weights='distance')
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
# Out:
# 0.9988183318601968

# %% [markdown]
# SO here we have finded the best parameters for our models and best accuracy from that models

# %% [markdown]
# # Saving the best model

# %%
import joblib

joblib.dump(svr, 'svrfile.obj')

svr_from_joblib=joblib.load('svrfile.obj')
