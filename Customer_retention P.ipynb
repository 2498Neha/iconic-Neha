# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_excel("customer_retention-1.xlsx")
ds
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
ds.to_csv('customer_retention-1.csv')

# %%
len(ds.columns)
# Out:
# 71

# %% [markdown]
# We have  71 columns in the dataframe

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %% [markdown]
# Till here we have imported the dataset.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# we can see the column names from the above code.

# %% [markdown]
# Firstly let's change the column names of the dataframe.

# %%
df=df.rename({'1Gender of respondent':'gender',
              '2 How old are you? ':'how_old',
              '3 Which city do you shop online from?':'city',
              '4 What is the Pin Code of where you shop online from?':'city_pincode',
              '5 Since How Long You are Shopping Online ?':'time_period',
              '6 How many times you have made an online purchase in the past 1 year?':'no_purchase',
              '7 How do you access the internet while shopping on-line?':'internet',
              '8 Which device do you use to access the online shopping?':'device_used',
              '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'ph_scr_size',
              '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'os_device',
              '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'browser_used',
              '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'channel_follow',
              '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'reach_the_store',
              '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'explore_time',
              '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'payment_option',
              '16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'abandon',
              '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ': 'bag_abandon',
              '18 The content on the website must be easy to read and understand':'content',
              '19 Information on similar product to the one highlighted  is important for product comparison':'info_similar_pr',
              '20 Complete information on listed seller and product being offered is important for purchase decision.':'complt_info',
              '21 All relevant information on listed products must be stated clearly':'info_of_pr',
              '22 Ease of navigation in website':'ease_of_website',
              '23 Loading and processing speed':'load_speed',
              '24 User friendly Interface of the website':'user_fr_inter',
              '25 Convenient Payment methods':'con_payment',
              '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'trust_transaction',
              '27 Empathy (readiness to assist with queries) towards the customers':'empathy',
              '28 Being able to guarantee the privacy of the customer':'gur_privacy',
              '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'avail_communi',
              '30 Online shopping gives monetary benefit and discounts':'monetary_benefits',
              '31 Enjoyment is derived from shopping online':'enjoy_shoponline',
              '32 Shopping online is convenient and flexible':'convenient_flexible',
              '33 Return and replacement policy of the e-tailer is important for purchase decision':'return_policy',
              '34 Gaining access to loyalty programs is a benefit of shopping online':'access_loyalty',
              '35 Displaying quality Information on the website improves satisfaction of customers':'dis_qua_info',
              '36 User derive satisfaction while shopping on a good quality website or application':'user_satisf',
              '37 Net Benefit derived from shopping online can lead to users satisfaction':'net_benefit',
              '38 User satisfaction cannot exist without trust':'satisf_wo_trust',
              '39 Offering a wide variety of listed product in several category':'wide_variety',
              '40 Provision of complete and relevant product information':'provision_prd',
              '41 Monetary savings':'monetary_savings',
              '42 The Convenience of patronizing the online retailer':'conven_of_retailer',
              '43 Shopping on the website gives you the sense of adventure':'sense_of_advent',
              '44 Shopping on your preferred e-tailer enhances your social status':'enhance_status',
              '45 You feel gratification shopping on your favorite e-tailer':'feel_gratif',
              '46 Shopping on the website helps you fulfill certain roles':'fulfill_roles',
              '47 Getting value for money spent':'value_for_money',
              'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'re_shopped',
              'Easy to use website or application':'easy_use',
              'Visual appealing web-page layout':'visual_appeal',
              'Wild variety of product on offer':'variety_offer',
              'Complete, relevant description information of products':'relevent_desc',
              'Fast loading website speed of website and application':'fast_website',
              'Reliability of the website or application':'reli_website',
              'Quickness to complete purchase':'quick_purchase',
              'Availability of several payment options':'sev_payment',
              'Speedy order delivery ':'speedy_del',
              'Privacy of customers’ information':'priv_cust',
              'Security of customer financial information':'sec_fin_info',
              'Perceived Trustworthiness':'trustworth',
              'Presence of online assistance through multi-channel':'online_assistance',
              'Longer time to get logged in (promotion, sales period)':'long_time_log',
              'Longer time in displaying graphics and photos (promotion, sales period)':'lon_time_dis',
              'Late declaration of price (promotion, sales period)':'late_dec_pr',
              'Longer page loading time (promotion, sales period)':'long_load_time',
              'Limited mode of payment on most products (promotion, sales period)':'lim_pay_mode',
              'Longer delivery period':'long_del_per',
              'Change in website/Application design':'ch_webs_dsgn',
              'Frequent disruption when moving from one page to another':'freq_dist',
              'Website is as efficient as before':'eff_website',
              'Which of the Indian online retailer would you recommend to a friend?':'reco_frnd'
            

             },axis=1)

# %%
df.columns
# Out:
# Index(['gender', 'how_old', 'city', 'city_pincode', 'time_period',
#        'no_purchase', 'internet', 'device_used', 'ph_scr_size', 'os_device',
#        'browser_used', 'channel_follow', 'reach_the_store', 'explore_time',
#        'payment_option', 'abandon', 'bag_abandon', 'content',
#        'info_similar_pr', 'complt_info', 'info_of_pr', 'ease_of_website',
#        'load_speed', 'user_fr_inter', 'con_payment', 'trust_transaction',
#        'empathy', 'gur_privacy', 'avail_communi', 'monetary_benefits',
#        'enjoy_shoponline', 'convenient_flexible', 'return_policy',
#        'access_loyalty', 'dis_qua_info', 'user_satisf', 'net_benefit',
#        'satisf_wo_trust', 'wide_variety', 'provision_prd', 'monetary_savings',
#        'conven_of_retailer', 'sense_of_advent', 'enhance_status',
#        'feel_gratif', 'fulfill_roles', 'value_for_money', 're_shopped',
#        'easy_use', 'visual_appeal', 'variety_offer', 'relevent_desc',
# ...

# %% [markdown]
# here we can see that we have changed the column names.

# %%
len(df.columns)
# Out:
# 71

# %% [markdown]
# We have 71 columns in our dataframe.

# %%
df.reco_frnd
# Out:
# 0                          Flipkart.com
# 1                 Amazon.in, Myntra.com
# 2      Amazon.in, Paytm.com, Myntra.com
# 3               Amazon.in, Flipkart.com
# 4                 Amazon.in, Myntra.com
#                      ...
# 264                           Amazon.in
# 265                        Flipkart.com
# 266                           Amazon.in
# 267                           Amazon.in
# 268                           Amazon.in
# Name: reco_frnd, Length: 269, dtype: object

# %%
df.reco_frnd.unique()
# Out:
# array(['Flipkart.com', 'Amazon.in, Myntra.com',
#        'Amazon.in, Paytm.com, Myntra.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Paytm.com',
#        'Flipkart.com, Paytm.com, Myntra.com, snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com'], dtype=object)

# %% [markdown]
# # Observation:
#
# From the target column we can see that it's a multiple logistic regression problem, where reco_frnd is our target varaible.

# %% [markdown]
# # Exploratory data Analysis

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# We have 269 rows and 71 columns.

# %%
df.dtypes
# Out:
# gender           int64
# how_old          int64
# city            object
# city_pincode     int64
# time_period      int64
#                  ...
# long_del_per    object
# ch_webs_dsgn    object
# freq_dist       object
# eff_website     object
# reco_frnd       object
# Length: 71, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      gender  how_old           city  city_pincode  time_period  no_purchase  \
# 0         0        3          Delhi        110009            5            4
# 1         1        2          Delhi        110030            5            5
# 2         1        2  Greater Noida        201308            4            5
# 3         0        2        Karnal         132001            4            1
# 4         1        2     Bangalore         530068            3            2
# ..      ...      ...            ...           ...          ...          ...
# 264       1        2          Solan        173212            2            1
# 265       1        3      Ghaziabad        201008            2            4
# 266       1        4     Bangalore         560010            3            1
# 267       1        1          Solan        173229            3            1
# 268       1        4      Ghaziabad        201009            3            4
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # To check missing values

# %%
df.isnull()
# Out:
#      gender  how_old   city  city_pincode  time_period  no_purchase  internet  \
# 0     False    False  False         False        False        False     False
# 1     False    False  False         False        False        False     False
# 2     False    False  False         False        False        False     False
# 3     False    False  False         False        False        False     False
# 4     False    False  False         False        False        False     False
# ..      ...      ...    ...           ...          ...          ...       ...
# 264   False    False  False         False        False        False     False
# 265   False    False  False         False        False        False     False
# 266   False    False  False         False        False        False     False
# 267   False    False  False         False        False        False     False
# 268   False    False  False         False        False        False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# gender          0
# how_old         0
# city            0
# city_pincode    0
# time_period     0
#                ..
# long_del_per    0
# ch_webs_dsgn    0
# freq_dist       0
# eff_website     0
# reco_frnd       0
# Length: 71, dtype: int64

# %% [markdown]
# Now we can check the null values using heatmap.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap we can see that no null values are present.

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#            gender     how_old   city_pincode  time_period  no_purchase  \
# count  269.000000  269.000000     269.000000   269.000000   269.000000
# mean     0.669145    2.959108  220465.747212     3.524164     2.672862
# std      0.471398    1.066012  140524.341051     1.436586     1.651788
# min      0.000000    1.000000  110008.000000     1.000000     1.000000
# 25%      0.000000    2.000000  122018.000000     3.000000     1.000000
# 50%      1.000000    3.000000  201303.000000     4.000000     2.000000
# 75%      1.000000    4.000000  201310.000000     5.000000     4.000000
# max      1.000000    5.000000  560037.000000     5.000000     5.000000
#
#          internet  device_used  ph_scr_size   os_device  browser_used  ...  \
# count  269.000000   269.000000   269.000000  269.000000    269.000000  ...
# mean     3.260223     1.676580     4.282528    1.776952      1.275093  ...
# std      1.135887     0.843904     0.923426    0.797892      0.645429  ...
# ...

# %% [raw]
# Key Observations:
#
# There is certain difference in mean and median which shows that outliers are present.
#
# There is little difference in 75% percentile and max column.
#
# We can see the large difference in 75% percentile and max in columns like city_pincode, browser_used,channel follow and abandon.
#
# We can see the little difference in columns like device used,ph_scr_size, payment option, content, info_similar_pr etc.

# %% [markdown]
# # Univariate Analysis

# %%
# Let's check the proportion of each type of income.
sns.countplot(x='reco_frnd',data=df)
plt.show()

# %% [markdown]
# Here we can see the class imbalance in our target column.

# %%
# another example of univariate analysis
df['gender'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in the gender column we have only two gender either male or female, so it is 0 or 1.

# %%
df['how_old'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can se the max shopping year is 5 years and least is 1 year and no outliers are present.

# %%
df['city_pincode'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here in the city pincode column we can see that few outliers are present.

# %%
df['time_period'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here also we can see that we  have no outliers.

# %%
df['no_purchase'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we cna see that no_purchase by the customers , here also we have no outliers.

# %%
df['internet'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %%
df['device_used'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in the device used column we can see that few outliers are present.

# %%
df['ph_scr_size'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can also see that few outliers are present.

# %%
df['os_device'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can also see that few outliers are present.

# %%
df['browser_used'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see many outliers are present.

# %%
df['channel_follow'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see many outliers are present.

# %%
df['reach_the_store'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we have no outliers.

# %%
df['explore_time'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we have no outliers.

# %%
df['payment_option'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that few outliers are present.

# %%
df['abandon'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that the median is at 3 and the other values are the outliers present.

# %%
df['bag_abandon'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see we have no outliers.

# %%
df['content'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we  can see few outliers are present.

# %%
df['info_similar_pr'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['complt_info'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see no outliers are present.

# %%
df['info_of_pr'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['ease_of_website'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['load_speed'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['user_fr_inter'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['con_payment'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['trust_transaction'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['empathy'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['gur_privacy'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %%
df['avail_communi'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['monetary_benefits'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %%
df['enjoy_shoponline'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %%
df['convenient_flexible'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['return_policy'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['access_loyalty'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %%
df['dis_qua_info'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %%
df['user_satisf'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['net_benefit'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['satisf_wo_trust'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['wide_variety'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['provision_prd'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['monetary_savings'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['conven_of_retailer'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %%
df['sense_of_advent'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['enhance_status'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['feel_gratif'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present.

# %%
df['fulfill_roles'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see few outliers are present

# %%
df['value_for_money'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers.

# %% [markdown]
# From the above plots we have seen the outliers present in our data.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# We are using scatter plots to see the relation of each column with the target column.

# %%
plt.scatter(df['gender'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the shhopping prefrences of gender in all classes.

# %%
plt.scatter(df['how_old'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see from how many years customer are shopping in all classses.

# %%
plt.scatter(df['city'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here in this column we can see the city of customer in all classes.

# %%
plt.scatter(df['city_pincode'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see th pincode of city in all classes.

# %%
plt.scatter(df['time_period'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we cna see the time period in all classes.

# %%
plt.scatter(df['no_purchase'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see the no_of purchase in all classes.

# %%
plt.scatter(df['internet'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the internet details in all the classes.

# %%
plt.scatter(df['device_used'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the device used by the custimer  in all classes.

# %%
plt.scatter(df['ph_scr_size'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the screen size of the phone used by the customer ti access the website .

# %%
plt.scatter(df['os_device'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the operating system device used by the cutomer.

# %%
plt.scatter(df['browser_used'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the bowser used by the customer in all the classes.

# %%
plt.scatter(df['channel_follow'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the channel followed by the cutomers in all classes to reach the website.

# %%
plt.scatter(df['reach_the_store'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see theat how customer reach the websites in all the classes.

# %%
plt.scatter(df['explore_time'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that how much time people explore the website in alll classes.

# %%
plt.scatter(df['payment_option'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that how many payment option is provided to the cutomer in all the classes.

# %%
plt.scatter(df['abandon'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the abandon made by the customer in the classees.

# %%
plt.scatter(df['bag_abandon'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here in we can see that why customer abndon the bag in all classes.

# %%
plt.scatter(df['content'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see the content ont he website in all the  classes.

# %%
plt.scatter(df['info_similar_pr'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see the silmilar product information displayed on the website in all the classes.

# %%
plt.scatter(df['complt_info'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the complete information displayed on the website in all the classes.

# %%
plt.scatter(df['info_of_pr'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the product information in all the classes.

# %%
plt.scatter(df['ease_of_website'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the ease of website in all the classes.

# %%
plt.scatter(df['load_speed'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the website loading speed in all the classes.

# %%
plt.scatter(df['user_fr_inter'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that  interface of the website is user friendly in all the website.

# %%
plt.scatter(df['con_payment'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the convenient payment method by the customer in all the classes.

# %%
plt.scatter(df['trust_transaction'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see the information regarding trust in the transaction in the classes.

# %%
plt.scatter(df['empathy'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the empathy of the cutomer in the classes.

# %%
plt.scatter(df['gur_privacy'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the privacy guranted by the websites in all the classes.

# %%
plt.scatter(df['avail_communi'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the communication facilities provided to the customer in all clases.

# %%
plt.scatter(df['monetary_benefits'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the monetary_benefits in all the classes.

# %%
plt.scatter(df['enjoy_shoponline'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that customer enjoy shopping online  in the classes.

# %%
plt.scatter(df['convenient_flexible'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see in all classees that shopping is convenient and flexible.

# %%
plt.scatter(df['return_policy'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the return policy provided by the websites in all the classes.

# %%
plt.scatter(df['access_loyalty'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the the benefit of loyalty programs acceess to the customer.

# %%
plt.scatter(df['dis_qua_info'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the quality information displayed on the website in all the classes.

# %%
plt.scatter(df['user_satisf'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the users satisfaction in all the classes.

# %%
plt.scatter(df['net_benefit'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see the benefits gain by the customer in all the clases.

# %%
plt.scatter(df['satisf_wo_trust'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that satisfaction can't be gain without trust.

# %%
plt.scatter(df['wide_variety'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that how much variety is present on the website in all the classes.

# %%
plt.scatter(df['provision_prd'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the provision of relevent inormation of the product in the classes.

# %%
plt.scatter(df['monetary_savings'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the monetary savings of the customer in all the customer.

# %%
plt.scatter(df['conven_of_retailer'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the convenience of the retailer in the classes.

# %%
plt.scatter(df['sense_of_advent'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the sensse of adventure gain by the customer in all the classes.

# %%
plt.scatter(df['enhance_status'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that how online shopping enhance the social status in all the classes.

# %%
plt.scatter(df['feel_gratif'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the feeling of gratification in the cutomer in all the classes.

# %%
plt.scatter(df['fulfill_roles'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we have people fulfill certain roles by shopping in all the classes.

# %%
plt.scatter(df['value_for_money'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we have sen customer are getting value for money spent in all the classes.

# %%
plt.scatter(df['re_shopped'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the retailer's people shopped from in all the classes.

# %%
plt.scatter(df['easy_use'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see is website easy to use in all the classes.

# %%
plt.scatter(df['visual_appeal'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see the visual appealing of the webpage layout in all the classes.

# %%
plt.scatter(df['variety_offer'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the variety of products on offer in all the classes.

# %%
plt.scatter(df['relevent_desc'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we see the complete relevent description of the product in all the classses.

# %%
plt.scatter(df['fast_website'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that website is loading fast in all the classes.

# %%
plt.scatter(df['reli_website'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the reliability of the website in all the classes.

# %%
plt.scatter(df['quick_purchase'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see th quickness in complete purchase in all the classes.

# %%
plt.scatter(df['sev_payment'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the availability of several payment option in all the classes.

# %%
plt.scatter(df['speedy_del'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the delivery of the website is speedy in all the classes.

# %%
plt.scatter(df['priv_cust'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the privacy of the customer information in all the classes.

# %%
plt.scatter(df['sec_fin_info'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the security of financial information in all the classes.

# %%
plt.scatter(df['trustworth'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the trustworthiness in all the classes.

# %%
plt.scatter(df['online_assistance'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see th assitance provided by the websites in all the classes.

# %%
plt.scatter(df['long_time_log'],df['reco_frnd'])
plt.show()

# %% [markdown]
# here we can see that longer time is taken to get logged in, in all  the websites.

# %%
plt.scatter(df['lon_time_dis'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the longer time taken in displaying graphics and photos on the website in all the classes.

# %%
plt.scatter(df['late_dec_pr'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the late declaration of price in all the claases.

# %%
plt.scatter(df['long_load_time'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the longer page loading time on the website in all the classes.

# %%
plt.scatter(df['lim_pay_mode'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the limiteed payment mode provided on the website in all the clases.

# %%
plt.scatter(df['long_del_per'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the longer delivery period on the website in all the classes.

# %%
plt.scatter(df['ch_webs_dsgn'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we have seen the chnages in website design in all the classes.

# %%
plt.scatter(df['freq_dist'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see the frequent distribution observed moving from one pagee to other on ll the websites.

# %%
plt.scatter(df['eff_website'],df['reco_frnd'])
plt.show()

# %% [markdown]
# Here we can see that website is efficient as before in all the classes.

# %% [raw]
# From the above scatter plots we have seen the relation of each column with the target column.

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Here we are using label encoding to convert all the string columns in ineger format.

# %%
# Applying Label encoding
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['city']=le.fit_transform(df['city'])

# %%
df['re_shopped']=le.fit_transform(df['re_shopped'])

# %%
df['easy_use']=le.fit_transform(df['easy_use'])

# %%
df['visual_appeal']=le.fit_transform(df['visual_appeal'])

# %%
df['variety_offer']=le.fit_transform(df['variety_offer'])

# %%
df['relevent_desc']=le.fit_transform(df['relevent_desc'])

# %%
df['fast_website']=le.fit_transform(df['fast_website'])

# %%
df['reli_website']=le.fit_transform(df['reli_website'])

# %%
df['quick_purchase']=le.fit_transform(df['quick_purchase'])

# %%
df['sev_payment']=le.fit_transform(df['sev_payment'])

# %%
df['speedy_del']=le.fit_transform(df['speedy_del'])

# %%
df['priv_cust']=le.fit_transform(df['priv_cust'])

# %%
df['sec_fin_info']=le.fit_transform(df['sec_fin_info'])

# %%
df['trustworth']=le.fit_transform(df['trustworth'])

# %%
df['online_assistance']=le.fit_transform(df['online_assistance'])

# %%
df['long_time_log']=le.fit_transform(df['long_time_log'])

# %%
df['lon_time_dis']=le.fit_transform(df['lon_time_dis'])

# %%
df['late_dec_pr']=le.fit_transform(df['late_dec_pr'])

# %%
df['long_load_time']=le.fit_transform(df['long_load_time'])

# %%
df['lim_pay_mode']=le.fit_transform(df['lim_pay_mode'])

# %%
df['long_del_per']=le.fit_transform(df['long_del_per'])

# %%
df['ch_webs_dsgn']=le.fit_transform(df['ch_webs_dsgn'])

# %%
df['freq_dist']=le.fit_transform(df['freq_dist'])

# %%
df['eff_website']=le.fit_transform(df['eff_website'])

# %%
df['reco_frnd']=le.fit_transform(df['reco_frnd'])

# %%
df.head()
# Out:
#    gender  how_old  city  city_pincode  time_period  no_purchase  internet  \
# 0       0        3     2        110009            5            4         4
# 1       1        2     2        110030            5            5         2
# 2       1        2     4        201308            4            5         3
# 3       0        2     6        132001            4            1         3
# 4       1        2     0        530068            3            2         2
#
#    device_used  ph_scr_size  os_device  ...  long_time_log  lon_time_dis  \
# 0            3            5          1  ...              0             0
# 1            1            2          3  ...              1             6
# 2            1            4          2  ...              7             6
# 3            1            4          3  ...              9             7
# 4            1            2          3  ...              5             8
#
#    late_dec_pr  long_load_time  lim_pay_mode  long_del_per  ch_webs_dsgn  \
# ...

# %% [markdown]
# Till here we have encode all the string columns in integer format.

# %% [markdown]
# # Multivariate Analysis

# %%
#Let's check the correlation matrix  {Example of multivariate analysis}
# method {'pearson'}

fi=plt.figure(figsize=(40,34))
hc=df.corr(method='pearson')
sns.heatmap(hc,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that we are not able to study this correlation matrix.

# %%
hc['reco_frnd'].sort_values(ascending=True)
# Out:
# browser_used          -0.262845
# provision_prd         -0.144946
# city                  -0.142123
# lon_time_dis          -0.140519
# convenient_flexible   -0.114768
#                          ...
# online_assistance      0.503836
# easy_use               0.541713
# reli_website           0.542711
# relevent_desc          0.680926
# reco_frnd              1.000000
# Name: reco_frnd, Length: 71, dtype: float64

# %% [raw]
# Observations:
# Now we can clearly identify the correlation of independent variable with target variable"reco_frnd" . the variables who has values less than 0.01 correlation value(has weak relationship)

# %% [markdown]
# # Data Cleaning

# %%
# We have observed that "sense of adventure" and "paymnent option" columns are highly negatively correlated colunms.

# So we are dropping highly negatively correlted columns.

# %%
hc.drop('sense_of_advent',axis=1,inplace=True)

# %%
hc.drop('payment_option',axis=1,inplace=True)

# %%
hc.drop('avail_communi',axis=1,inplace=True)

# %%
hc.columns
# Out:
# Index(['gender', 'how_old', 'city', 'city_pincode', 'time_period',
#        'no_purchase', 'internet', 'device_used', 'ph_scr_size', 'os_device',
#        'browser_used', 'channel_follow', 'reach_the_store', 'explore_time',
#        'abandon', 'bag_abandon', 'content', 'info_similar_pr', 'complt_info',
#        'info_of_pr', 'ease_of_website', 'load_speed', 'user_fr_inter',
#        'con_payment', 'trust_transaction', 'empathy', 'gur_privacy',
#        'monetary_benefits', 'enjoy_shoponline', 'convenient_flexible',
#        'return_policy', 'access_loyalty', 'dis_qua_info', 'user_satisf',
#        'net_benefit', 'satisf_wo_trust', 'wide_variety', 'provision_prd',
#        'monetary_savings', 'conven_of_retailer', 'enhance_status',
#        'feel_gratif', 'fulfill_roles', 'value_for_money', 're_shopped',
#        'easy_use', 'visual_appeal', 'variety_offer', 'relevent_desc',
#        'fast_website', 'reli_website', 'quick_purchase', 'sev_payment',
# ...

# %% [markdown]
# From the above columns we have seen that both the columns are dropped.

# %%
# Removing the outliers

# %% [markdown]
# We have very few outlier in the many columns , so no need to remove the outlier.

# %% [markdown]
# # Checking for skewness

# %%
hc.skew()
# Out:
# gender          1.850288
# how_old         3.606127
# city            2.211409
# city_pincode    2.325754
# time_period     2.845795
#                   ...
# long_del_per    0.765065
# ch_webs_dsgn    0.377670
# freq_dist       0.011339
# eff_website     0.850097
# reco_frnd       0.736198
# Length: 68, dtype: float64

# %% [markdown]
# From the above code we have seen that skewenss is present in many columns, so we will remove it by applying appropriate method.

# %% [markdown]
# # Separating independent variable and target variable.

# %%
x1=hc.drop('reco_frnd',axis=1)
y=hc['reco_frnd']

# %% [markdown]
# # Removing skewness

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x1)
df_new=pd.DataFrame(df_new,columns=x1.columns)

# %%
df_new.skew()
# Out:
# gender         -0.034053
# how_old        -0.023094
# city           -0.137760
# city_pincode   -0.217265
# time_period    -0.176119
#                   ...
# lim_pay_mode    0.004781
# long_del_per    0.019845
# ch_webs_dsgn    0.032143
# freq_dist      -0.017068
# eff_website    -0.004039
# Length: 67, dtype: float64

# %% [markdown]
# skewness has been removed from the data.
