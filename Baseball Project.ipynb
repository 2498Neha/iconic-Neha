# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv('baseball.csv')
ds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
 df=pd.DataFrame(data=ds)
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Till here we have imported the dataset into the pandas dataframe.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Here we can see that we have 30 rows and 17 columns.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# df.columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# We can see that the W is categorical column, Thus it is a classification problem

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [raw]
# Key Observations:
#
# 1 Here we can see that mean  and median values are almo similar in all the columns.
#
# 2 There is a small diifference in 75% percentile and max  in all the columns like R ,AB,H etc.
#
# 3 We can also see some large difference in few columns like SHO and E columns
#  these column shows  outliers present in the  column.

# %% [markdown]
# Exploring data variables

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [raw]
# Target/dependent variable is described and categorical in nature.
#
# W score scale ranges from 63 to 100
#
# Where 63 is least win matches.
#
# where 100 is highest win matches.

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# Observations:
#
# W has few  of the values  concetrated  in the categories of 68,81,74,76,83.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# To check missing values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dataset has no missing values.
#
# If there were any, you would've noticed in figure represented by different
# colour shade.

# %% [markdown]
# # Univariate Analysis

# %%
# Let's check the proportion of each type of W {example of univariate analysis}
sns.countplot(x='W',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# So here we can see the class imbalance in our datset.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# using boxplot
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in the runs column we can see that the few outliers are present the outlier is above the 75% percentile and ranges between 850 and 900.

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in the AB(at bats) column we don't have any outliers.

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in the H(hits) column we can see that we don't have any outliers,we can also see that most of the data is above the 50% percentile.

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the 2B column we also do not have any outliers ,here also we can see that more than 50% data is below the median.

# %%
df['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this 3B columnn we also do not have any outliers  and the data is properly distributed
# in 25%,50%and 75% percentile.

# %%
df['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this HR column we don't have any outliers but most of the data is 75% percentile.

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In this BB column we also don't have any outliers but the median is close to 75%  percentile.

# %%
df['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In this SO column we also don't have any outliers, but we can see that median is close to the 75% percentile.

# %%
df['SB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in SB column we have no outliers  but we can see that more than 50 percent of data is above the median.

# %%
df['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we also don't have any outliers ,here we can see most of the data is below the 50% percentile.

# %%
df['ER'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we have no outliers present,but the median is close to 75% percentile

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in ERA column we can see that few outliers are present above the 75% percentile.

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in CG column we can see that we have no outliers but most of the data is above the median.

# %%
df['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we have few outliers present ,we can also see that median is colse to the 75% percentile.

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in SV column we have few outliers present above the 75% percentile.

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in E column we can see that we have many outliers present above the 75%
# percentile.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.scatter(df['R'],df['W'])

# %% [markdown]
# here we can see a positive relation as the runs increases no. of wins also increases.

# %%
plt.scatter(df['AB'],df['W'])

# %% [markdown]
# Here we are not able to see any positive linear relation  between the two columns, as the AB increases
# sometimes wins increses and sometimes decreases also.

# %%
plt.scatter(df['H'],df['W'])

# %% [markdown]
# Here we can also see that no linear relation is present between both sometimes wins increses with H sometimes decreses with H.

# %%
plt.scatter(df['2B'],df['W'])

# %% [markdown]
# Here we can see a positive relation between both the columns as the 2B increses
# no. of wins also increases.

# %%
plt.scatter(df['3B'],df['W'])

# %% [markdown]
# wHere i  thi column we are not finding any linear realtion between both the columns.

# %%
plt.scatter(df['HR'],df['W'])

# %% [markdown]
# Here we can see a positvie relation as the HR increses wins also increse.

# %%
plt.scatter(df['BB'],df['W'])

# %% [markdown]
# Here we can the positve relation as the BB column increses W also increases.

# %%
plt.scatter(df['SO'],df['W'])

# %% [markdown]
# Here we can see that wins are seen in a particualr range of SO, as it increses wins increases

# %%
plt.scatter(df['SB'],df['W'])

# %% [markdown]
# Here also we have not a linear relation between both the columns.

# %%
plt.scatter(df['RA'],df['W'])

# %% [markdown]
# here we can see a negative relation as the RA incereases wins decreses.

# %%
plt.scatter(df['ER'],df['W'])

# %% [markdown]
# Here alos we can see the negative relation between both the columns as the ER decreses wins increses.

# %%
plt.scatter(df['ERA'],df['W'])

# %% [markdown]
# Here we can see also see  a negative relation between both the columns as the ERA increses wins decreases and we can see  few outliers also.

# %%
plt.scatter(df['CG'],df['W'])

# %% [markdown]
# Here in this column we are not finding any linear relation between both the columns

# %%
plt.scatter(df['SHO'],df['W'])

# %% [markdown]
# Here we can see a positve relation but some outliers are alos present.

# %%
plt.scatter(df['SV'],df['W'])

# %% [markdown]
# Here we can see that as SV increses wins also increses.

# %%
plt.scatter(df['E'],df['W'])

# %% [markdown]
# Here we can see that not a linear relation is present but some outliers are presnt.

# %% [raw]
# So by plotting scatter plots we have seen the relation of all the columns with the target column.

# %%
sns.pairplot(df)

# %% [markdown]
# So here we  can see the relation of each column with the target column.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # To check Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.heatmap(dfcor)# example of multivariate analysis
# Out:
# <AxesSubplot:>

# %% [raw]
# Observations:
# Dark shades are  highly correlated.

# %%
plt.figure(figsize=(24,14))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Light shades are highly correlated
#
# So we can see that SV column is highly positively correlated with W with correlation value0.67.
#
# Here BB column is also highly positivey correlated with W .
#
# Here we can see that the column named ERA,ER and RA are highly negatively correlated with the win column., these column are impacting are data in a negative way.
#
# Some other columns like R ,2B,SHO are also highly positively correlated.

# %% [markdown]
# # To  Check distribution of skewness

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %% [markdown]
# here we can seetaht normal distribution is present in only one curve whole data is not normally distributed.

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %% [markdown]
# Here we can also see that curve is not normally distributed i sslightly bent outwward from right.

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %% [markdown]
# Here we can see that the curve is not normally distributed.

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %% [markdown]
# Here also skewness is present  as the curve is slightly skewwed from left.

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %% [markdown]
# here we can see that curve slightly skewwed from the right.

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %% [markdown]
# Here we can clearly see that curve is not normally distributed.

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness in the above column, as the curve is bent to the right.

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness  in the column.

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %% [markdown]
# Here we can see that the curve is skewwed from the right.

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %% [markdown]
# Here in this column we can see the skewness from the left of the curve.

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %% [markdown]
# here also we can see that the curve is slightly skewwed from the left.

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %% [markdown]
# Here the curve is normally distributed but slightly streched towards left.

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %% [markdown]
# here we see that the column is highly skewwed .

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %% [markdown]
# Here also we can see that the cureve skewwed from the right.

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %% [markdown]
# here in this column we can see the skewness   as the curve is kewwed from the right.

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# Here in his column we can see that the curve is not normally distributed.

# %% [markdown]
# From the above plots we can see that some columns are highly skewwed and others are slightly skewwed.

# %% [markdown]
# # Data Cleaning

# %%
# Dropping the highly correlated columns
df.drop('RA',axis=1,inplace=True)

# %%
df.drop('ER',axis=1,inplace=True)

# %%
df.drop('ERA',axis=1,inplace=True)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0  95  724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1  83  696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2  81  669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3  76  622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4  74  689  5605  1515  289  49  151  455  1259   83   7   12  35   86

# %%
df.shape
# Out:
# (30, 14)

# %% [markdown]
# So we can see that the columns are dropped.

# %% [markdown]
# # Removing The Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 5.39806195e-01, 8.14628593e-01,
#         1.67160651e+00, 4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 5.39806195e-01, 1.72800005e-01,
#         2.49879323e-01, 6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 2.77264091e+00, 3.20914294e-01,
#         6.54856158e-01, 1.11724227e+00],
#        [4.83244373e-01, 1.14641931e+00, 2.41521620e-01, 4.01088140e-01,
#         8.28122030e-01, 4.18423371e-01, 8.83180700e-01, 1.16053598e+00,
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z[5][1]
# Out:
# 3.5096470447193067

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 6    87  764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# 12   85  661  5417  1331  243  21  176  435  1150   52   2   12  46   93
# ...

# %%
df.shape
# Out:
# (30, 14)

# %%
df_new.shape
# Out:
# (29, 14)

# %% [markdown]
# we can see that 1 row ois deleted as an outlier.

# %% [markdown]
# checking for skewness

# %% [markdown]
# # Separating independent variable and target variable.

# %%
x1=df_new.drop('W',axis=1)
y1=df_new['W']

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# We can see the skewness in five columns, now we are removing it by appliying appropriate
# method.

# %%
x1['H']=np.log(x1['H'])
sns.histplot(x1['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %%
x1['CG']=np.sqrt(x1['CG'])
sns.histplot(x1['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %%
x1['SHO']=np.sqrt(x1['SHO'])
sns.histplot(x1['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %%
x1['SV']=np.sqrt(x1['SV'])
sns.histplot(x1['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %%
x1['E']=np.log(x1['E'])
sns.histplot(x1['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %%
x1.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# CG    -0.260678
# SHO   -0.085802
# SV     0.370280
# E      0.583308
# dtype: float64

# %% [markdown]
# So we can see that skewness is removed from the columns.

# %%
x1
# Out:
#       R    AB         H   2B  3B   HR   BB    SO   SB        CG       SHO  \
# 0   724  5575  7.311218  300  42  139  383   973  104  1.414214  2.828427
# 1   696  5467  7.207119  277  44  156  439  1264   70  1.414214  3.464102
# 2   669  5439  7.240650  303  29  141  533  1157   86  3.316625  3.162278
# 3   622  5533  7.230563  260  27  136  404  1231   68  2.645751  3.000000
# 4   689  5605  7.323171  289  49  151  455  1259   83  2.645751  3.464102
# 6   764  5567  7.242082  272  19  212  554  1227   63  1.732051  2.000000
# 7   713  5485  7.222566  246  20  217  418  1331   44  0.000000  3.162278
# 8   644  5485  7.232010  278  32  167  436  1310   87  1.000000  3.464102
# 9   748  5640  7.309881  294  33  161  478  1148   71  1.732051  3.162278
# 10  751  5511  7.257708  279  32  172  503  1233  101  2.236068  3.000000
# 11  729  5459  7.217443  278  26  230  486  1392  121  2.236068  3.605551
# 12  661  5417  7.193686  243  21  176  435  1150   52  1.414214  3.464102
# ...

# %% [markdown]
# Here we can see that their is not a large difference in ranges of columns.So need to scale our data.

# %% [markdown]
# # Handling class imbalance  by undersampling the majority class.

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
x_under,y_under=SM.fit_resample(x1,y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-f8ddf0af66db> in <module>
#       1 SM=SMOTE()
# ----> 2 x_under,y_under=SM.fit_resample(x1,y1)
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = label_binarize(output[1], np.unique(y)) if binarize_y else output[1]
#
# ~\anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     307
#     308             self.nn_k_.fit(X_class)
# --> 309             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     310             X_new, y_new = self._make_samples(
#     311                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# ...

# %% [markdown]
# # Creating Train test split

# %%
x=x1
x.shape
# Out:
# (30, 13)

# %%
y=y1
y.shape
# Out:
# (30,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (30, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
x_train.shape
# Out:
# (22, 13)

# %%
y_train.shape
# Out:
# (22, 1)

# %%
y_test.shape
# Out:
# (8, 1)

# %%
x_test.shape
# Out:
# (8, 13)

# %% [markdown]
# # Finding best Algorithm using multiple models.

# %%
mnb=MultinomialNB()
svc=SVC()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()

# %% [raw]
# model=[mnb,dtc,knn,svc]
# for m in model:
#     m.fit(x_train,y_train)
#     pred=m.predict(x_test)
#     print('accuracy:',m)
#     print(acccuracy_score(y_test,pred))
#     print(confusion_matrix(y_test,pred))
#     print(classification_report(y_test,pred))
