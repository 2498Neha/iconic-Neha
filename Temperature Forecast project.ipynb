# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv('temperature.csv')
ds
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %% [markdown]
# Till here we have imported the dataset

# %%
df.Next_Tmax.unique()
# Out:
# array([29.1, 30.5, 31.1, 31.7, 31.2, 31.5, 30.9, 31.3, 32.6, 31.4, 30.8,
#        33.1, 31.8, 30.6, 32. , 24.8, 27.3, 28.1, 27.9, 28.2, 28.9, 27.6,
#        27.1, 27.5, 26.8, 28.7, 27.8, 29.2, 28.8, 30. , 30.1, 29.4, 31.6,
#        30.2, 30.4, 32.5, 31. , 25.2, 28.4, 28.3, 27.4, 26.2, 28. , 26.7,
#        28.6, 27.7, 28.5, 30.7, 29.6, 29.9, 29.3, 32.2, 33.6, 30.3, 32.3,
#        29.8, 29.7, 29.5, 29. , 23.4, 26.4, 26.6, 26.1, 25.4, 27.2, 27. ,
#        26.3, 25.5, 25.6, 25.9, 23. , 26.5, 26. , 25.7, 22.4, 25.8, 25.1,
#        24.9, 24.3, 24.5, 25.3, 21.8, 24.7, 25. , 24.6, 23.6, 24.1, 23.2,
#        23.7, 24.2, 23.8, 23.9, 31.9, 23.1, 33. , 32.7, 26.9, 32.1, 33.3,
#        32.4, 33.4, 33.5, 34.8, 34. , 34.3, 34.5,  nan, 32.8, 33.7, 33.2,
#        32.9, 34.1, 34.9, 35.3, 34.6, 35. , 33.9, 34.7, 36.6, 34.4, 35.8,
#        35.2, 33.8, 35.6, 35.1, 34.2, 36. , 35.5, 35.4, 21.6, 23.5, 24.4,
#        24. , 35.9, 36.1, 22.5, 22.8, 36.2, 21.1, 23.3, 22. , 22.7, 20.9,
# ...

# %%
df.Next_Tmin.unique()
# Out:
# array([21.2, 22.5, 23.9, 24.3, 24. , 23.4, 22.9, 21.6, 21. , 24.5, 22.2,
#        22.8, 20.9, 21.1, 23. , 23.7, 23.2, 24.2, 18.7, 21.5, 21.8, 22.3,
#        21.3, 20.7, 19.8, 20.8, 21.7, 22.1, 20.5, 21.9, 17.8, 20.1, 20.3,
#        19.4, 19.1, 18.9, 20. , 19.7, 19.5, 20.6, 23.1, 23.3, 22.7, 22.6,
#        22.4, 22. , 23.5, 23.8, 21.4, 19.3, 20.4, 19.9, 20.2, 24.1, 23.6,
#        24.4, 24.8, 25.1, 24.6, 24.7, 25. , 24.9, 25.3, 26. , 26.1, 25.5,
#        25.8, 25.4, 25.6, 25.7, 25.2, 25.9, 26.3, 26.2, 26.4, 26.5, 26.9,
#         nan, 26.8, 26.6, 27. , 27.1, 26.7, 27.5, 27.2, 27.4, 27.7, 28.3,
#        27.6, 28. , 27.3, 19.6, 19.2, 18.6, 18.5, 18.2, 18.4, 18.8, 17.9,
#        17.5, 16.5, 18. , 19. , 16.7, 18.1, 18.3, 28.1, 28.4, 29.4, 29.1,
#        28.5, 28.8, 29.8, 29.5, 28.6, 17.1, 16.8, 17.6, 17.4, 15.8, 16.9,
#        17.7, 17.2, 15.5, 16.6, 16.4, 16.3, 17. , 14.7, 15.9, 16. , 17.3,
#        15.4, 15.3, 13.8, 15.6, 15.1, 27.9, 28.7, 27.8, 28.2, 13.3, 14.1,
# ...

# %%
df.Next_Tmax.value_counts()
# Out:
# 29.3    113
# 33.0    106
# 31.3    104
# 29.6    101
# 31.2     98
#        ...
# 37.3      1
# 37.6      1
# 19.7      1
# 21.5      1
# 38.7      1
# Name: Next_Tmax, Length: 183, dtype: int64

# %%
df.Next_Tmin.value_counts()
# Out:
# 23.5    159
# 23.4    157
# 24.0    156
# 23.2    150
# 23.8    149
#        ...
# 29.5      1
# 13.6      1
# 13.3      1
# 13.9      1
# 12.9      1
# Name: Next_Tmin, Length: 157, dtype: int64

# %% [markdown]
# We have two dependent variable nemed Next Tmax and Next_Tmin.

# %% [raw]
# We can see that Next_Tmax and Next_Tmin column is our dependent variable and is continous in nature, thus it is a Linear Regression problem.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# As we can see that we have many null values in this dataset.

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see the null values in the heatmap.

# %% [markdown]
# # Statistical Summary|

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %% [raw]
# key observations:
#
# 1 The difference in mean and median is almost similar all the columns.
#
# 2 Their is no difference in 75% percentile and max in many columns like LDAPS_CC1,LDAPS_CC2,LDAPS_CC3,LDAPS_CC4,latand lon, which shows
# that no outliers are present in these columns.
#
# 3 There is a large difference in many column like LDAPS_RHmin,LDAPS_RHmax,LDAPS_WS,LDAPS_LH which showws rhat extreme outliers are
#  present in these columns.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# So we are using boxplot for univariate analysis

# %%
df['station'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can  see that we have no outliers in this column.

# %%
df['Present_Tmax'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here in this column we can see that extreme outliers ranges below 22.5.

# %%
df['Present_Tmin'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that outliers are ranges above 30.5 and below 17.5.

# %%
df['LDAPS_RHmin'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers in this column.

# %%
df['LDAPS_RHmax'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that extreme outliers are present below 70.

# %%
df['LDAPS_Tmax_lapse'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can also see that extreme outliers are present.

# %%
df['LDAPS_Tmin_lapse'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can also see that extreme outliers are present below 18.

# %%
df['LDAPS_WS'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can also see that extreme outliers are present above 10.

# %%
df['LDAPS_LH'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can also see that extreme outliers are present above 150.

# %%
df['LDAPS_CC1'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers in this column.

# %%
df['LDAPS_CC2'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers

# %%
df['LDAPS_CC3'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers

# %%
df['LDAPS_CC4'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers

# %%
df['LDAPS_PPT1'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here in this column we have extrme outliers only.

# %%
df['LDAPS_PPT2'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here also in this column we have extrme outliers only.

# %%
df['LDAPS_PPT3'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also in this column we have extrme outliers only.

# %%
df['LDAPS_PPT4'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also in this column we have extrme outliers only.

# %%
df['lat'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that we have no outliers in this column.

# %%
df['lon'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers in this column.

# %%
df['DEM'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column the outliers ranges above 100.

# %%
df['Slope'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that outliers ranges above 4.

# %%
df['Solar radiation'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers in this column.

# %%
df['Next_Tmax'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column outliers ranges below 25.

# %%
df['Next_Tmin'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here we can see the outliers above 30.0 and below 17.5.

# %% [markdown]
# From the above outliers we have seen the outliers present in all the columns,and the median position.

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# Now we are plotting scatter plotsto see the relation of each column with target column.

# %% [raw]
# Since wehave 2 targetcolumn thus firstly we plotting  for Next_Tmax column only.

# %%
sns.scatterplot(data=df,x='station' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='station', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see that their is a positive relation in both the columns.

# %%
sns.scatterplot(data=df,x='Date' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see the max temp. according to the date .

# %%
sns.scatterplot(data=df,x='Present_Tmax' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Next_Tmax'>

# %% [markdown]
# here we can see that as the present tmax increases next tmax also increases.

# %%
sns.scatterplot(data=df,x='Present_Tmin' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Next_Tmax'>

# %% [markdown]
# here we can see that as the present tmin increases next tmax also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_RHmin' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Next_Tmax'>

# %% [markdown]
# Here in this column we can see a negative relation in both columns as the next_tmax is increasing LDAPS_RHmin decreases.

# %%
sns.scatterplot(data=df,x='LDAPS_RHmax' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Next_Tmax'>

# %% [markdown]
# here in this column we can see that their is a positive relation in both the columns and many outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_Tmax_lapse' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmax'>

# %% [markdown]
# here we can see  apositive relation as next_Tmax increases Ldaps_tmax _lapse also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_Tmin_lapse' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmax'>

# %% [markdown]
# here we can see apositive relation as next_Tmin increases Ldaps_tmax _lapse also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_WS' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see that we have negative relation in both columns as Next_tmax increases LDAPS_ws Dcreases.

# %%
sns.scatterplot(data=df,x='LDAPS_LH' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see that we have negative relation in both columns as Next_tmax increases LDAPS_LH decreases.

# %%
sns.scatterplot(data=df,x='LDAPS_CC1' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see a linear relation between both the columns.

# %%
sns.scatterplot(data=df,x='LDAPS_CC2' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Next_Tmax'>

# %% [markdown]
# Here also we can see a linear relation between both the columns.

# %%
sns.scatterplot(data=df,x='LDAPS_CC3' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Next_Tmax'>

# %% [markdown]
# Here also we can see a linear relation between both the columns.

# %%
sns.scatterplot(data=df,x='LDAPS_CC4' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmax'>

# %% [markdown]
# Here also we can see a linear relation between both the columns.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT1' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Next_Tmax'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT1,and may outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT2' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Next_Tmax'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT2,and many outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT3' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Next_Tmax'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT3,and many outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT4' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmax'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT4 ,and many outliers are also present.

# %%
sns.scatterplot(data=df,x='lat' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='lat', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see a linear relation in both the columns.

# %%
sns.scatterplot(data=df,x='lon' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='lon', ylabel='Next_Tmax'>

# %% [markdown]
# Here we can see a linear relation in both the columns.

# %%
sns.scatterplot(data=df,x='DEM' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='Next_Tmax'>

# %% [markdown]
# Here also we can see a linear relation in both the column.

# %%
sns.scatterplot(data=df,x='Slope' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='Slope', ylabel='Next_Tmax'>

# %% [markdown]
# Here also we can see a linear relation in both the column and many outliers are also present.

# %%
sns.scatterplot(data=df,x='Solar radiation' ,y='Next_Tmax')
# Out:
# <AxesSubplot:xlabel='Solar radiation', ylabel='Next_Tmax'>

# %% [markdown]
# here we can see that temp increses with increases in solar radiation.

# %% [raw]
# Now we  are plotting for the 2nd target column Next_Tmin.

# %%
sns.scatterplot(data=df,x='station' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='station', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see that their is a positive relation in both the columns.

# %%
sns.scatterplot(data=df,x='Date' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see the min temp. according to the date .

# %%
sns.scatterplot(data=df,x='Present_Tmax' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Next_Tmin'>

# %% [markdown]
# here we can see that as the present tmax increases next tmin also increases.

# %%
sns.scatterplot(data=df,x='Present_Tmin' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Next_Tmin'>

# %% [markdown]
# here we can see that as the present tmin increases next tmin also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_RHmin' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Next_Tmin'>

# %% [markdown]
# here in this columns we can see that as nexxt_tmin increases LDAPS_RHMIN also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_RHmax' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Next_Tmin'>

# %% [markdown]
# here in this column we can see that their is a positive relation in both the columns and many outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_Tmax_lapse' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmin'>

# %% [markdown]
# here we can see apositive relation as next_Tmin increases Ldaps_tmax _lapse also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_Tmin_lapse' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmin'>

# %% [markdown]
# here we can see apositive relation as next_Tmin increases Ldaps_tmax _lapse also increases.

# %%
sns.scatterplot(data=df,x='LDAPS_WS' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see that we have negative relation in both columns as Next_tmin increases LDAPS_ws Dcreases.

# %%
sns.scatterplot(data=df,x='LDAPS_LH' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see that we have negative relation in both columns as Next_tmin increases LDAPS_LH decreases.

# %%
sns.scatterplot(data=df,x='LDAPS_CC1' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see a linear relation between both the columns.

# %%
sns.scatterplot(data=df,x='LDAPS_CC2' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Next_Tmin'>

# %% [markdown]
# Here also we can see a linear relation between both the columns.

# %%
sns.scatterplot(data=df,x='LDAPS_CC3' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Next_Tmin'>

# %% [markdown]
# Here also we can see a linear relation between both the columns and we can also see many outliers.

# %%
sns.scatterplot(data=df,x='LDAPS_CC4' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmin'>

# %% [markdown]
# Here also we can see a linear relation between both the columns and we can also see many outliers.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT1' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Next_Tmin'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT1,and may outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT2' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Next_Tmin'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT2,and many outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT3' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Next_Tmin'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT3,and many outliers are also present.

# %%
sns.scatterplot(data=df,x='LDAPS_PPT4' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmin'>

# %% [markdown]
# Here in this column we can see that Temp increaes with decreases in LDAPS_PPT4 ,and many outliers are also present.

# %%
sns.scatterplot(data=df,x='lat' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='lat', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see a linear relation in both the columns.

# %%
sns.scatterplot(data=df,x='lon' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='lon', ylabel='Next_Tmin'>

# %% [markdown]
# Here we can see a linear relation in both the columns.

# %%
sns.scatterplot(data=df,x='DEM' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='Next_Tmin'>

# %% [markdown]
# Here also we can see a linear relation in both the column.

# %%
sns.scatterplot(data=df,x='Slope' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='Slope', ylabel='Next_Tmin'>

# %% [markdown]
# Here also we can see a linear relation in both the column and Some outliers are also present.

# %%
sns.scatterplot(data=df,x='Solar radiation' ,y='Next_Tmin')
# Out:
# <AxesSubplot:xlabel='Solar radiation', ylabel='Next_Tmin'>

# %% [markdown]
# here we can see that temp increses with increases in solar radiation.

# %% [markdown]
# From the above plots we have seen the relation of each column with the target column.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# Tocheck correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113211      0.132419    -0.067122
# Present_Tmax      0.113211      1.000000      0.618760    -0.206782
# Present_Tmin      0.132419      0.618760      1.000000     0.124921
# LDAPS_RHmin      -0.067122     -0.206782      0.124921     1.000000
# LDAPS_RHmax      -0.168010     -0.304209     -0.015334     0.579141
# LDAPS_Tmax_lapse  0.069561      0.575289      0.470118    -0.564580
# LDAPS_Tmin_lapse  0.105422      0.629247      0.772921     0.089476
# LDAPS_WS          0.005320     -0.122876     -0.035111     0.294361
# LDAPS_LH         -0.134226      0.136716     -0.009368    -0.070858
# LDAPS_CC1         0.006956     -0.314863      0.085593     0.613818
# LDAPS_CC2         0.003414     -0.215816      0.091439     0.745443
# LDAPS_CC3         0.000698     -0.145513     -0.002839     0.689679
# LDAPS_CC4         0.006159     -0.142497     -0.045091     0.514075
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that light shades are highly correlated.

# %%
plt.figure(figsize=(20,14))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# Observation:
#
# 1 Here light shades are positevely correlated
#
# 2 We can see that many columns like LDAPS_RHmin,LDAPS_CC1,LDAPS_CC2,LDAPS_CC3,
#   LDAPS_CC4 are highly negativly corrrelated with the target column.
#
# 3 Some columns like LDAPS_Tmax_lapse and LDAOS_Tmin_lapse are highly positively correlated with the target column.
#
# 4 Some other columns are alos positively correlated like present tmax, present_tmin.

# %% [raw]
# # another example of multivariate analysis
# sns.pairplot(df)

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Here we can clearly see the relation of each column with other columns.

# %% [markdown]
# # To check skewness

# %%
sns.distplot(df['station'])
# Out:
# <AxesSubplot:xlabel='station', ylabel='Density'>

# %% [markdown]
# Here we can see that the curve is not normally distributed.

# %%
sns.distplot(df['Present_Tmax'])
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss the curve is not normally distributed.

# %%
sns.distplot(df['Present_Tmin'])
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss the curve is not normally distributed.

# %%
sns.distplot(df['LDAPS_RHmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Density'>

# %% [markdown]
# Here we can see that curve is skewwed from the right.

# %%
sns.distplot(df['LDAPS_RHmax'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Density'>

# %% [markdown]
# Here we can see that curve is skewwed from the left.

# %%
sns.distplot(df['LDAPS_Tmax_lapse'])
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Density'>

# %% [markdown]
# here the curve is slightly skewed from the left.

# %%
sns.distplot(df['LDAPS_Tmin_lapse'])
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Density'>

# %% [markdown]
# here we can see that curve is slightly skewwed from the left.

# %%
sns.distplot(df['LDAPS_WS'])
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Density'>

# %% [markdown]
# here we can see that curve is slightly skewwed from the right.

# %%
sns.distplot(df['LDAPS_LH'])
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Density'>

# %% [markdown]
# Here we can see that curve is skewwed from both sides.

# %%
sns.distplot(df['LDAPS_CC1'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Density'>

# %% [markdown]
# Here we can see the skewness in all the curves.

# %%
sns.distplot(df['LDAPS_CC2'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness in all the curves.

# %%
sns.distplot(df['LDAPS_CC3'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Density'>

# %% [markdown]
# here we can see that all the curves are skewwed from the right.

# %%
sns.distplot(df['LDAPS_CC4'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Density'>

# %% [markdown]
# here we can see that all the curves are skewwed from the right

# %%
sns.distplot(df['LDAPS_PPT1'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Density'>

# %% [markdown]
# Here we can see that curve is slightly skewwed from the right.

# %%
sns.distplot(df['LDAPS_PPT2'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Density'>

# %% [markdown]
# Here we can see that curve is slightly skewwed from the right.

# %%
sns.distplot(df['LDAPS_PPT3'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Density'>

# %% [markdown]
# Here we can see that curve is slightly skewwed from the right.

# %%
sns.distplot(df['LDAPS_PPT4'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Density'>

# %% [markdown]
# Here also we can see that curve is slightly skewwed from the right.

# %%
sns.distplot(df['lat'])
# Out:
# <AxesSubplot:xlabel='lat', ylabel='Density'>

# %% [markdown]
# Here  also we can see that all the curves are not normally distributed.

# %%
sns.distplot(df['lon'])
# Out:
# <AxesSubplot:xlabel='lon', ylabel='Density'>

# %% [markdown]
# Here also we can see that all the curves are not normally distributed.

# %%
sns.distplot(df['Slope'])
# Out:
# <AxesSubplot:xlabel='Slope', ylabel='Density'>

# %% [markdown]
# Here also we can see that all the curves are not normally distributed.

# %%
sns.distplot(df['Solar radiation'])
# Out:
# <AxesSubplot:xlabel='Solar radiation', ylabel='Density'>

# %% [markdown]
# here we can see that curve is skewwed from the left.

# %%
sns.distplot(df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='Next_Tmax', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness in the plot.

# %%
sns.distplot(df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='Next_Tmin', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness in the plot.

# %% [markdown]
# From  the above plots we have seen the skewness in all the plots.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Deleting the highly correlated columns.

# %%
df.drop('LDAPS_RHmin',axis=1,inplace=True)

# %%
df.drop('LDAPS_CC1',axis=1,inplace=True)

# %%
df.drop('LDAPS_CC2',axis=1,inplace=True)

# %%
df.drop('LDAPS_CC3',axis=1,inplace=True)

# %%
df.drop('LDAPS_CC4',axis=1,inplace=True)

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    91.116364
# 1      2.0  30-06-2013          31.9          21.6    90.604721
# 2      3.0  30-06-2013          31.6          23.3    83.973587
# 3      4.0  30-06-2013          32.0          23.4    96.483688
# 4      5.0  30-06-2013          31.4          21.9    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_PPT1  \
# 0         28.074101         23.006936  6.818887   69.451805         0.0
# 1         29.850689         24.035009  5.691890   51.937448         0.0
# 2         30.091292         24.565633  6.138224   20.573050         0.0
# 3         29.704629         23.326177  5.650050   65.727144         0.0
# 4         29.113934         23.486480  5.735004  107.965535         0.0
#
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# ...

# %% [markdown]
# So we can see that highly correlated columns are deleted.

# %% [markdown]
# # Label encoding

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['Date']=le.fit_transform(df['Date'])

# %%
df.head()
# Out:
#    station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0      1.0   290          28.7          21.4    91.116364         28.074101
# 1      2.0   290          31.9          21.6    90.604721         29.850689
# 2      3.0   290          31.6          23.3    83.973587         30.091292
# 3      4.0   290          32.0          23.4    96.483688         29.704629
# 4      5.0   290          31.4          21.9    90.155128         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0         23.006936  6.818887   69.451805         0.0         0.0         0.0
# 1         24.035009  5.691890   51.937448         0.0         0.0         0.0
# 2         24.565633  6.138224   20.573050         0.0         0.0         0.0
# 3         23.326177  5.650050   65.727144         0.0         0.0         0.0
# 4         23.486480  5.735004  107.965535         0.0         0.0         0.0
#
# ...

# %% [markdown]
# Here we can see that date column is noew in integer format.

# %% [markdown]
# # Treating the missing values.

# %%
df['station'].fillna(df['station'].median(),inplace=True)

# %%
df['Date'].fillna(df['Date'].median(),inplace=True)

# %%
df['Present_Tmax'].fillna(df['Present_Tmax'].median(),inplace=True)

# %%
df['Present_Tmin'].fillna(df['Present_Tmin'].median(),inplace=True)

# %%
df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].median(),inplace=True)

# %%
df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].median(),inplace=True)

# %%
df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].median(),inplace=True)

# %%
df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].median(),inplace=True)

# %%
df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].median(),inplace=True)

# %%
df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].median(),inplace=True)

# %%
df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].median(),inplace=True)

# %%
df['Next_Tmin'].fillna(df['Next_Tmin'].median(),inplace=True)

# %%
df['Next_Tmax'].fillna(df['Next_Tmax'].median(),inplace=True)

# %%
df['LDAPS_WS'].fillna(df['LDAPS_WS'].median(),inplace=True)

# %%
df['LDAPS_LH'].fillna(df['LDAPS_LH'].median(),inplace=True)

# %%
df.head()
# Out:
#    station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0      1.0   290          28.7          21.4    91.116364         28.074101
# 1      2.0   290          31.9          21.6    90.604721         29.850689
# 2      3.0   290          31.6          23.3    83.973587         30.091292
# 3      4.0   290          32.0          23.4    96.483688         29.704629
# 4      5.0   290          31.4          21.9    90.155128         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0         23.006936  6.818887   69.451805         0.0         0.0         0.0
# 1         24.035009  5.691890   51.937448         0.0         0.0         0.0
# 2         24.565633  6.138224   20.573050         0.0         0.0         0.0
# 3         23.326177  5.650050   65.727144         0.0         0.0         0.0
# 4         23.486480  5.735004  107.965535         0.0         0.0         0.0
#
# ...

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# Here we can see that we have removed all the null values from the dataset.

# %% [markdown]
# # Removing the Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.6643153 , 1.51331319, 0.36172509, ..., 1.51793488, 0.37652986,
#         0.69782911],
#        [1.52562236, 1.51331319, 0.72067506, ..., 1.22994952, 0.07184549,
#         0.17429753],
#        [1.38692941, 1.51331319, 0.61920005, ..., 1.21653443, 0.26400635,
#         0.38950571],
#        ...,
#        [1.6643153 , 1.66971658, 2.22210036, ..., 2.0743251 , 0.7928784 ,
#         2.22815219],
#        [0.        , 1.73674661, 3.30450051, ..., 2.35821196, 4.12366669,
#         4.68472344],
#        [0.        , 1.73674661, 2.64870034, ..., 1.51793488, 2.76209758,
#         2.76553364]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64), array([ 7, 10, 10, ..., 10, 11, 12], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmax  \
# 0         1.0   290          28.7          21.4    91.116364
# 1         2.0   290          31.9          21.6    90.604721
# 2         3.0   290          31.6          23.3    83.973587
# 3         4.0   290          32.0          23.4    96.483688
# 4         5.0   290          31.4          21.9    90.155128
# ...       ...   ...           ...           ...          ...
# 7745     21.0   304          23.1          17.8    78.261383
# 7746     22.0   304          22.5          17.4    83.690018
# 7747     23.0   304          23.3          17.1    78.869858
# 7748     24.0   304          23.3          17.7    77.294975
# 7749     25.0   304          23.2          17.4    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_PPT1  \
# 0            28.074101         23.006936  6.818887   69.451805         0.0
# 1            29.850689         24.035009  5.691890   51.937448         0.0
# ...

# %%
df.shape
# Out:
# (7752, 20)

# %%
df_new.shape
# Out:
# (6894, 20)

# %% [markdown]
# we can see that 858 rows are deleted as an outlier.

# %%
# Removing Skewness

# %%
df_new1=pd.DataFrame(data=df_new)

# %%
df_new1=df_new1.drop('Next_Tmax',axis=1)

# %%
df_new1=df_new1.drop('Next_Tmin',axis=1)

# %%
df_new1.shape
# Out:
# (6894, 18)

# %%
x1=pd.DataFrame(data=df_new1)

# %%
 x1.head()
# Out:
#    station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0      1.0   290          28.7          21.4    91.116364         28.074101
# 1      2.0   290          31.9          21.6    90.604721         29.850689
# 2      3.0   290          31.6          23.3    83.973587         30.091292
# 3      4.0   290          32.0          23.4    96.483688         29.704629
# 4      5.0   290          31.4          21.9    90.155128         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0         23.006936  6.818887   69.451805         0.0         0.0         0.0
# 1         24.035009  5.691890   51.937448         0.0         0.0         0.0
# 2         24.565633  6.138224   20.573050         0.0         0.0         0.0
# 3         23.326177  5.650050   65.727144         0.0         0.0         0.0
# 4         23.486480  5.735004  107.965535         0.0         0.0         0.0
#
# ...

# %%
y=df_new.loc[0:7753,'Next_Tmax':'Next_Tmin']

# %%
y.shape
# Out:
# (6894, 2)

# %%
y
# Out:
#       Next_Tmax  Next_Tmin
# 0          29.1       21.2
# 1          30.5       22.5
# 2          31.1       23.9
# 3          31.7       24.3
# 4          31.2       22.5
# ...         ...        ...
# 6891       25.8       23.2
# 6892       27.1       24.2
# 6893       26.5       23.3
# 6894       25.5       23.4
# 6895       26.6       24.2
#
# [6170 rows x 2 columns]

# %%
x1.skew()
# Out:
# station             0.002792
# Date                0.008120
# Present_Tmax       -0.273950
# Present_Tmin       -0.227590
# LDAPS_RHmax        -0.694148
# LDAPS_Tmax_lapse   -0.110448
# LDAPS_Tmin_lapse   -0.386322
# LDAPS_WS            1.097251
# LDAPS_LH            0.574066
# LDAPS_PPT1          3.749975
# LDAPS_PPT2          4.869067
# LDAPS_PPT3          5.515722
# LDAPS_PPT4          5.969876
# lat                 0.108251
# lon                -0.275508
# DEM                 1.764031
# Slope               1.593600
# Solar radiation    -0.505353
# dtype: float64

# %% [markdown]
# we can see the skewness in many columns.

# %%
from sklearn.preprocessing import power_transform
df1=power_transform(x1)
df1=pd.DataFrame(df1,columns=x1.columns)

# %%
df1.skew()
# Out:
# station            -0.201793
# Date               -0.274273
# Present_Tmax       -0.031957
# Present_Tmin       -0.021875
# LDAPS_RHmax        -0.100101
# LDAPS_Tmax_lapse   -0.011239
# LDAPS_Tmin_lapse   -0.025390
# LDAPS_WS            0.005909
# LDAPS_LH           -0.028195
# LDAPS_PPT1          1.624705
# LDAPS_PPT2          1.826222
# LDAPS_PPT3          2.004598
# LDAPS_PPT4          2.284110
# lat                 0.091387
# lon                -0.189409
# DEM                 0.038729
# Slope               0.233805
# Solar radiation    -0.166145
# dtype: float64

# %% [markdown]
# So we can see that skewenss is removed from the columns.

# %% [markdown]
# # Creating Train test Split

# %%
x.shape
# Out:
# (6894, 18)

# %%
y.shape
# Out:
# (6894, 2)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=52)

# %%
x_train.shape
# Out:
# (4825, 18)

# %%
x_test.shape
# Out:
# (2069, 18)

# %%
y_test.shape
# Out:
# (2069, 2)

# %%
y_train.shape
# Out:
# (4825, 2)

# %%
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # Finding Best Algorithm using multiple models.

# %%
lm=LinearRegression()
dtr=DecisionTreeRegressor()
rd=RandomForestRegressor()
knr=KNeighborsRegressor()

# %%
m=[lm,dtr,rd,knr]

# %%
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('score:',m)
    print(r2_score(y_test,pred))
# Out:
# score: LinearRegression()
# 0.7596383716224854
# score: DecisionTreeRegressor()
# 0.6963522119780661
# score: RandomForestRegressor()
# 0.8496177311682978

# %% [markdown]
# from the above result we are getting highest r2_score with Random forest regressor.

# %% [markdown]
# # Cross_Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('score:',m)
    print(score)
    print(score.mean())
# Out:
# score: LinearRegression()
# [0.70410114 0.62774001 0.73224211 0.77718194 0.72019412]
# 0.7122918647140969
# score: DecisionTreeRegressor()
# [0.05484999 0.32890148 0.38028689 0.54150863 0.47815656]
# 0.3567407087816581
# score: RandomForestRegressor()
# [0.62681092 0.60922078 0.69904919 0.77483696 0.69540373]
# 0.6810643160045251

# %% [markdown]
# So here we are getting highest cross val score from linear regression model,it also contains least difference in cross_val_score and r2_score.

# %% [markdown]
# So Linear regression is our best model

# %% [markdown]
# # Saving the best model

# %%
import joblib

joblib.dump(lm,'lmfile.obj')

lm_from_joblib=joblib.load('lmfile.obj')
