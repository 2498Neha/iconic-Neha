# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_excel('Data_Train.xlsx')
ds
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
ds.to_csv('Data_Train.csv')

# %%
ds
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# Till here we have imported thed dataset.

# %%
df.Price.unique()
# Out:
# array([ 3897,  7662, 13882, ...,  9790, 12352, 12648], dtype=int64)

# %%
df.Price.value_counts()
# Out:
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 9502       1
# 13875      1
# 7742       1
# 5703       1
# 4098       1
# Name: Price, Length: 1870, dtype: int64

# %% [markdown]
# We can see that price is our dependent variable and is continous in nature, thus it is a Linear regression Problem.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# As we can see that we have few null values in this dataset.

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we have only few values that's why they are not shown in the plot.

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [raw]
# Observations:
#
# we have all other columns in string format  thus we are not able to analyse them.
#
# Their is a difference in mean and median is present.
#
# Their is huge difference in max and 75% percentile, which shows that outliers may be present.

# %% [markdown]
# we have most of all columns in string format , so for further analysis convert all columns in integer format.

# %% [markdown]
# # Label Encoding

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
dt=df.apply(le.fit_transform)
dt
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            3               24       0            5     18       211
# 1            1                6       3            0     84        31
# 2            4               43       2            1    118        70
# 3            3               10       3            0     91       164
# 4            3                0       0            5     29       149
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               41       3            0     64       183
# 10679        1               29       3            0     64       193
# 10680        4               29       0            2     18        58
# 10681       10                0       0            5     18        92
# 10682        1               42       2            1    108        85
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# ...

# %%
dt.dtypes
# Out:
# Airline            int32
# Date_of_Journey    int32
# Source             int32
# Destination        int32
# Route              int32
# Dep_Time           int32
# Arrival_Time       int32
# Duration           int32
# Total_Stops        int32
# Additional_Info    int32
# Price              int64
# dtype: object

# %% [markdown]
# So as we can see from the above all the string columns are converted in integer fromat.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# So we are using Boxplot

# %%
dt['Airline'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that extreme outliers are present.

# %%
dt['Date_of_Journey'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that we have no outliers.

# %%
dt['Source'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that few have outliers are present.

# %%
dt['Destination'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that we have no outliers.

# %%
dt['Route'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %%
dt['Dep_Time'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %%
dt['Arrival_Time'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %%
dt['Duration'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %%
dt['Total_Stops'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %%
dt['Additional_Info'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here we can see that many outliers are present.

# %%
dt['Price'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here also we can see that we have no outliers.

# %% [markdown]
# From the above the plots we have seen that extreme outliers are present.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Now we are plotting scatter plotsto see the relation of each column with target column.

# %%
sns.scatterplot(data=df,x='Airline' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %% [markdown]
# here we can see that price increases with different airlines many outliers are prresent, which are prices more than average,

# %%
sns.scatterplot(data=df,x='Date_of_Journey' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Price'>

# %% [markdown]
# Here we can see a linear relation that price increases at some range only after that few price are present only.

# %%
sns.scatterplot(data=df,x='Source' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Price'>

# %% [markdown]
# here we can see the price according to the places for some places prices are  high for some price are low.

# %%
sns.scatterplot(data=df,x='Destination' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='Price'>

# %% [markdown]
# here also we can see the price according to the places for some places prices are high for some price are low.

# %%
sns.scatterplot(data=df,x='Route' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Route', ylabel='Price'>

# %% [markdown]
# Here we can see that price increases for some route and decrases for some routes.

# %%
sns.scatterplot(data=df,x='Dep_Time' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Price'>

# %% [markdown]
# Here we can see that price rapidly increases only when time is different from average dep_time.

# %%
sns.scatterplot(data=df,x='Arrival_Time' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Arrival_Time', ylabel='Price'>

# %% [markdown]
# Here we can see that price rapidly increases only when time is different from average Arrival_time.

# %%
sns.scatterplot(data=df,x='Duration' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Price'>

# %% [markdown]
# Here also we can see that price rapidly increases only when time is different from average duration

# %%
sns.scatterplot(data=df,x='Total_Stops' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Total_Stops', ylabel='Price'>

# %% [markdown]
# Here we can see that price is more for less stops , if more stops are price is high.

# %%
sns.scatterplot(data=df,x='Additional_Info' ,y='Price')
# Out:
# <AxesSubplot:xlabel='Additional_Info', ylabel='Price'>

# %% [markdown]
# Here additional info has little effect on price but many outliers are their.

# %% [markdown]
# From the above plots we have seen the relation of each column with the target column.

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# To check correlation

# %%
dtcor=dt.corr()
dtcor
# Out:
#                   Airline  Date_of_Journey    Source  Destination     Route  \
# Airline          1.000000         0.022251 -0.013401     0.018479  0.025039
# Date_of_Journey  0.022251         1.000000  0.167549    -0.273357  0.275233
# Source          -0.013401         0.167549  1.000000    -0.592574  0.403378
# Destination      0.018479        -0.273357 -0.592574     1.000000 -0.461169
# Route            0.025039         0.275233  0.403378    -0.461169  1.000000
# Dep_Time        -0.039439        -0.007836  0.055191    -0.063608 -0.082080
# Arrival_Time    -0.015733        -0.012507  0.020844    -0.036830  0.010523
# Duration         0.027917        -0.001168 -0.192009     0.022037 -0.062111
# Total_Stops      0.035732        -0.043846 -0.225557     0.337756 -0.437362
# Additional_Info -0.060802         0.008382 -0.022107     0.026806  0.035216
# Price           -0.043030         0.002629  0.085124    -0.156205  0.243202
#
# ...

# %%
sns.heatmap(dtcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that light shades are highly correlated.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(dtcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# Observations:
#
# Light shades are highly positively correlated.
#
# Here we can see that total  stops column is highly negatively correlated with the target column.
#
# Route column is positively correlated with the tarrget column.
#
# Some other columns are also positively correlated  with target column like source ,arrivaltime.

# %%
# another example of multivariate analysis
sns.pairplot(dt)

# %% [markdown]
# Here we can clearly see the relation of each column with other columns.

# %% [markdown]
# # To check skewness

# %%
sns.distplot(dt['Airline'])
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Density'>

# %% [markdown]
# Here we can see the skewenss in all the cureves.

# %%
sns.distplot(dt['Date_of_Journey'])
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Density'>

# %% [markdown]
# Here we can see the skewenss in all the curves.

# %%
sns.distplot(dt['Source'])
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves.

# %%
sns.distplot(dt['Destination'])
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves,the curves are not normally distributed.

# %%
sns.distplot(dt['Route'])
# Out:
# <AxesSubplot:xlabel='Route', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves,the curves are not normally distributed.

# %%
sns.distplot(dt['Dep_Time'])
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves,the curves are not normally distributed.

# %%
sns.distplot(dt['Arrival_Time'])
# Out:
# <AxesSubplot:xlabel='Arrival_Time', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves,the curves are not normally distributed.

# %%
sns.distplot(dt['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves

# %%
sns.distplot(dt['Total_Stops'])
# Out:
# <AxesSubplot:xlabel='Total_Stops', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves

# %%
sns.distplot(dt['Additional_Info'])
# Out:
# <AxesSubplot:xlabel='Additional_Info', ylabel='Density'>

# %% [markdown]
# Here  we can see that curves are slightly skewwed.

# %%
sns.distplot(dt['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in all the curves

# %% [markdown]
# From the above plots we have seen the skewness in allthe columns.

# %% [markdown]
# # Data cleaning

# %%
dt.drop('Total_Stops',axis=1,inplace=True)

# %%
dt.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        3               24       0            5     18       211
# 1        1                6       3            0     84        31
# 2        4               43       2            1    118        70
# 3        3               10       3            0     91       164
# 4        3                0       0            5     29       149
#
#    Arrival_Time  Duration  Additional_Info  Price
# 0           233       240                8     65
# 1           906       336                8    669
# 2           413       106                8   1537
# 3          1324       311                8    389
# 4          1237       303                8   1457

# %% [markdown]
# we can see that total stops is dropped.

# %%
# Removing null values.

# %%
dt['Route'].fillna(dt['Route'].median(),inplace=True)

# %%
dt.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# Here we can see that we have removed all the null values from the dataset.

# %% [markdown]
# # Removing the Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(dt))
z
# Out:
# array([[0.41067545, 0.02147223, 1.65844074, ..., 0.42287466, 0.49989167,
#         1.31032812],
#        [1.26099927, 1.4375315 , 0.89005213, ..., 1.30672664, 0.49989167,
#         0.24864943],
#        [0.01448647, 1.56153172, 0.04055451, ..., 0.81083539, 0.49989167,
#         1.27707426],
#        ...,
#        [0.01448647, 0.42675104, 1.65844074, ..., 0.79114632, 0.49989167,
#         0.36290293],
#        [2.56545795, 1.92386608, 1.65844074, ..., 0.40446108, 0.49989167,
#         0.99583487],
#        [1.26099927, 1.48047596, 0.04055451, ..., 1.40800134, 0.49989167,
#         0.79369406]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  785,  1043,  2079,  2405,  2481,  2495,  2556,  2924,  3032,
#         3111,  3700,  3788,  4521,  5013,  5372,  5628,  6024,  6336,
#         6576,  7724,  8957,  9019,  9657, 10364, 10511], dtype=int64), array([8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        8, 8, 8], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Additional_Info  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m         No info
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m         No info
# ...

# %%
dt.shape
# Out:
# (10683, 10)

# %%
df_new.shape
# Out:
# (10658, 10)

# %% [markdown]
# WE can see that 25 rows are deleted as outliers.

# %% [markdown]
# # removing Skewness

# %% [markdown]
# Separating independent variable and target variable.

# %%
x1=df_new.drop('Price',axis=1)
y1=df_new['Price']

# %%
x1.skew()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# we have no skewenss .

# %% [markdown]
# # Creating Train test split

# %%
x=x1
x.shape
# Out:
# (10658, 9)

# %%
y=y1
y.shape
# Out:
# (10658,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (10658, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=52)

# %%
x_train.shape
# Out:
# (7460, 9)

# %%
x_test.shape
# Out:
# (3198, 9)

# %%
y_test.shape
# Out:
# (3198, 1)

# %%
y_train.shape
# Out:
# (7460, 1)

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # Finding Best Algorithm using multiple models.

# %%
lm=LinearRegression()
dtr=DecisionTreeRegressor()
svr=SVR()
knr=KNeighborsRegressor()
ls=Lasso(alpha=0.0001)
rd=Ridge(alpha=0.0001)

# %%
model=[lm,dtr,svr,knr,ls,rd]

for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('error:',m)
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Mean squared error:',mean_squared_error(y_test,pred))
    print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-f01c133df08b> in <module>
#       2
#       3 for m in model:
# ----> 4     m.fit(x_train,y_train)
#       5     pred=m.predict(x_test)
#       6     print('error:',m)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...
