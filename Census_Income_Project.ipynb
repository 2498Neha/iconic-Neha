# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv('census_income.csv')
ds
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# Till Here wwe have imported the dataset

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.Income
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32555     <=50K
# 32556      >50K
# 32557     <=50K
# 32558     <=50K
# 32559      >50K
# Name: Income, Length: 32560, dtype: object

# %%
df.Income.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %% [markdown]
# # Observation:

# %% [raw]
# By looking the dataset we can easily see that it's Logistic Regression problem, as we can see Income is our target variable.

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# We can see that we have 32560 rows and 15 columns.

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # To check missing values

# %%
df.isnull()
# Out:
#          Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32555  False      False   False      False          False           False
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
#
#        Occupation  Relationship   Race    Sex  Capital_gain  Capital_loss  \
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# Here we can see that we have no null values in our dataset.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap we can see that no null values are present.

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [raw]
# Key Observations:
#
# There is a small difference  im mean and 50% percentile median.
#
# Thereis a huge difference in 75% percentile and max column in many columns.

# %%
# Let's check the proportion of each type of income.
sns.countplot(x='Income',data=df)
plt.show()

# %% [markdown]
# Here we can see the class imbalance in our dataset.

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
# another example of univariate analysis
df['Age'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that many outliers are present , which shows the ages of the peoples which is more than average.

# %%
df['Fnlwgt'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that extreme outliers are present.

# %%
df['Education_num'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here alos we  can see that outliers are present.

# %%
df['Capital_gain'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that extreme outliers are present.

# %%
df['Capital_loss'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that extreme outliers are present.

# %%
df['Hours_per_week'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In this column we can also see that outliers are present.

# %% [raw]
# From the above plots we can see the outliers present  in our dataset , by using appropriate method.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# We are using scatter plots to see the relation of each column with the target column.

# %%
plt.scatter(df['Age'],df['Income'])
plt.show()

# %% [markdown]
# Here we can see the income of the peoples according to their ages in both classes also some outliers are present.

# %%
plt.scatter(df['Workclass'],df['Income'])
plt.show()

# %% [markdown]
# Here in the workclass column we can  see the workclass of each class  peolpes.

# %%
plt.scatter(df['Fnlwgt'],df['Income'])
plt.show()

# %% [markdown]
# Here in this column we can see the relation of final weight with the Income, we can also see the outliers.

# %%
plt.scatter(df['Education'],df['Income'])
plt.show()

# %% [markdown]
# here in this column we can see that education is present in both the classes and their incomes depends on it.

# %%
plt.scatter(df['Education_num'],df['Income'])
plt.show()

# %% [markdown]
# here we can see the relation of education_num with the incomeof both classes peoples.

# %%
plt.scatter(df['Marital_status'],df['Income'])
plt.show()

# %% [markdown]
# Here we can seee the marital status of all the people in both the classes.

# %%
plt.scatter(df['Occupation'],df['Income'])
plt.show()

# %% [markdown]
# here we can see the impact of occupation of peoples on their incomes.

# %%
plt.scatter(df['Relationship'],df['Income'])
plt.show()

# %% [markdown]
# Herewe can see the impact of relationshhip of peoples on their income.

# %%
plt.scatter(df['Race'],df['Income'])
plt.show()

# %% [markdown]
# Here we can see the relation of race  with the income .

# %%
plt.scatter(df['Sex'],df['Income'])
plt.show()

# %% [markdown]
# Here we can see that both males and females are present in both the classes.

# %%
plt.scatter(df['Capital_gain'],df['Income'])
plt.show()

# %% [markdown]
# Here we can see the capital gain acc. to the income, we can also see that many outliers are present.

# %%
plt.scatter(df['Capital_loss'],df['Income'])
plt.show()

# %% [markdown]
# Here we can see the capital loss according to the income we can also see the outliers.

# %%
plt.scatter(df['Hours_per_week'],df['Income'])
plt.show()

# %% [markdown]
# Here in this column we can see the working hour per week with respect to the income we can also see that outliers are present.

# %%
plt.scatter(df['Native_country'],df['Income'])
plt.show()

# %% [markdown]
# Here we can see the relation of native country with the income.we can also see the present outliers.

# %% [raw]
# From the above scatter plot we have seen the relation of each column with the target column.

# %% [markdown]
# # Multivariate Analysis

# %% [raw]
# Here we are not able to apply the correlation because the target column is in string format.

# %%
# another example pf multivariate analysis
sns.pairplot(df)

# %% [markdown]
# From the above pairplot we can see the relation of each column with other columns.

# %% [markdown]
# # To Check distribution of skewness

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Here we can  see the skewness in the curve it's not normally distributed.

# %%
sns.distplot(df['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewenss in the column Fnlwgt.

# %%
sns.distplot(df['Education_num'])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %% [markdown]
# Here in this column also we can see the skewness.

# %%
sns.distplot(df['Capital_gain'])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %% [markdown]
# Here also we can see tha the curve is skewwed from the right.

# %%
sns.distplot(df['Capital_loss'])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %% [markdown]
# Here also we can see the skwness in the second curve.

# %%
sns.distplot(df['Hours_per_week'])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Density'>

# %% [markdown]
# Here we can see the skewness in all the curves,they are not normally distributed.

# %% [markdown]
# From the above plots we have seen the skewness present in our dataset.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We can see that we have many columns in string format.we have to chnage it in integer format.

# %% [markdown]
# # Label Encoding

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['Workclass']=le.fit_transform(df['Workclass'])

# %%
df['Education']=le.fit_transform(df['Education'])

# %%
df['Marital_status']=le.fit_transform(df['Marital_status'])

# %%
df['Occupation']=le.fit_transform(df['Occupation'])

# %%
df['Relationship']=le.fit_transform(df['Relationship'])

# %%
df['Race']=le.fit_transform(df['Race'])

# %%
df['Sex']=le.fit_transform(df['Sex'])

# %%
df['Native_country']=le.fit_transform(df['Native_country'])

# %%
df['Income']=le.fit_transform(df['Income'])

# %% [markdown]
# We have encoded all the columns so let's see the results.

# %%
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %% [raw]
# So as we can see from the above all the string columns are converted in integer format.

# %% [markdown]
# # Now we can check the correlation.

# %%
dfcor=df.corr()
dfcor
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.077674   0.033828  0.000437   0.030047       0.122627
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# ...

# %%
plt.figure(figsize=(22,12))
sns.heatmap(dfcor,annot=True,cmap='YlOrRd_r')
# Out:
# <AxesSubplot:>

# %% [raw]
# Light shades are highly correlated
#
# So we see that Education_num column is highly positively correlated  with correlation value 0.34.
#
# We can see that age, sex , capital_gain and hours per week column are  also positively correlated with income column.
#
# We can see that marital_status and relationship columns are negatively correlated with income column with correlation value-0.2 and -0.25.
#
# Some other columns are also slightly positively correlated with the income column.

# %%
# Dropping the highly negatively correlated columns.

# %%
df.drop('Marital_status',axis=1,inplace=True)

# %%
df.drop('Relationship',axis=1,inplace=True)

# %% [markdown]
# We have dropped the highly negatively correlated columns.
#
# So let's check it.

# %%
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Occupation  Race  Sex  \
# 0   50          6   83311          9             13           4     4    1
# 1   38          4  215646         11              9           6     4    1
# 2   53          4  234721          1              7           6     2    1
# 3   28          4  338409          9             13          10     2    0
# 4   37          4  284582         12             14           4     4    0
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13              39       0
# 1             0             0              40              39       0
# 2             0             0              40              39       0
# 3             0             0              40               5       0
# 4             0             0              40              39       0

# %%
df.shape
# Out:
# (32560, 13)

# %% [markdown]
# So we can see that the columns are dropped.

# %% [markdown]
# # Removing The Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.83709708, 1.46388339, 1.0087417 , ..., 2.22212013, 0.29157343,
#         0.5632099 ],
#        [0.04264043, 0.09012148, 0.24504633, ..., 0.03542999, 0.29157343,
#         0.5632099 ],
#        [1.05703146, 0.09012148, 0.42576955, ..., 0.03542999, 0.29157343,
#         0.5632099 ],
#        ...,
#        [1.42358875, 0.09012148, 0.3588108 , ..., 0.03542999, 0.29157343,
#         0.5632099 ],
#        [1.21562378, 0.09012148, 0.11092744, ..., 1.65520046, 0.29157343,
#         0.5632099 ],
#        [0.98372   , 0.77700244, 0.92986178, ..., 0.03542999, 0.29157343,
#         1.77553698]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([11, 10,  6, ...,  6,  6,  6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Occupation  Race  \
# 0       50          6   83311          9             13           4     4
# 1       38          4  215646         11              9           6     4
# 2       53          4  234721          1              7           6     2
# 4       37          4  284582         12             14           4     4
# 5       49          4  160187          6              5           8     2
# ...    ...        ...     ...        ...            ...         ...   ...
# 32555   27          4  257302          7             12          13     4
# 32556   40          4  154374         11              9           7     4
# 32557   58          4  151910         11              9           1     4
# 32558   22          4  201490         11              9           1     4
# 32559   52          5  287927         11              9           4     4
#
#        Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.shape
# Out:
# (32560, 13)

# %%
df_new.shape
# Out:
# (27417, 13)

# %% [markdown]
# We can see that 5143 rows are deleted as outliers.

# %% [raw]
# Checking for Skewness

# %% [markdown]
# # Separating independent variable and target variable.

# %%
x1=df.drop('Income',axis=1)
y1=df['Income']

# %%
x1.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Occupation         0.114540
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x1)
df_new=pd.DataFrame(df_new,columns=x1.columns)

# %%
df_new.skew()
# Out:
# Age              -0.013897
# Workclass         0.061629
# Fnlwgt            0.016914
# Education        -0.309431
# Education_num     0.023885
# Occupation       -0.187152
# Race             -2.010817
# Sex              -0.719244
# Capital_gain      3.016951
# Capital_loss      4.299511
# Hours_per_week    0.229556
# Native_country   -2.725467
# dtype: float64

# %% [raw]
# Here we have removed all the skewness.

# %% [markdown]
# # Handling class imbalance problem by using oversampling the minority class

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
x_over,y_over=SM.fit_resample(x1,y1)

# %%
y_over.value_counts()
# Out:
# 1    24719
# 0    24719
# Name: Income, dtype: int64

# %% [markdown]
# So we can see that class is balanced.

# %% [markdown]
# # Creating Train Test split

# %%
x=x_over
x.shape
# Out:
# (49438, 12)

# %%
y=y_over
y.shape
# Out:
# (49438,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (49438, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (34606, 12)

# %%
x_test.shape
# Out:
# (14832, 12)

# %%
y_train.shape
# Out:
# (34606, 1)

# %%
y_test.shape
# Out:
# (14832, 1)

# %% [markdown]
# # Finding Best Algorithm using multiple models.

# %%
lg=LogisticRegression()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
gnb=GaussianNB()
rf=RandomForestClassifier()
ad=AdaBoostClassifier()
svc=SVC()

# %%
model=[lg,dtc,knn,gnb,rf,ad,svc]

for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('accuracy_score:',m)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
# Out:
# accuracy_score: LogisticRegression()
# 0.6212918015102481
# [[6904  505]
#  [5112 2311]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.93      0.71      7409
#            1       0.82      0.31      0.45      7423
#
#     accuracy                           0.62     14832
#    macro avg       0.70      0.62      0.58     14832
# weighted avg       0.70      0.62      0.58     14832
#
# accuracy_score: DecisionTreeClassifier()
# 0.8236245954692557
# [[6031 1378]
#  [1238 6185]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      7409
#            1       0.82      0.83      0.83      7423
#
#     accuracy                           0.82     14832
#    macro avg       0.82      0.82      0.82     14832
# weighted avg       0.82      0.82      0.82     14832
#
# accuracy_score: KNeighborsClassifier()
# 0.7122437971952535
# [[4930 2479]
#  [1789 5634]]
# ...

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('score:',m)
    print(score)
    print(score.mean())
# Out:
# score: LogisticRegression()
# [0.62166262 0.62722492 0.6355178  0.62213007 0.64347122]
# 0.6300013268870274
# score: DecisionTreeClassifier()
# [0.71885113 0.79581311 0.8638754  0.85809649 0.86558107]
# 0.820443440080024
# score: KNeighborsClassifier()
# [0.71460356 0.71692961 0.73675162 0.73935471 0.7329827 ]
# 0.7281244404816497
# score: GaussianNB()
# [0.62813511 0.62459547 0.62692152 0.6266815  0.62819864]
# 0.6269064498411336
# score: RandomForestClassifier()
# [0.75212379 0.83525485 0.90978964 0.91291595 0.91483767]
# 0.8649843801297706
# score: AdaBoostClassifier()
# [0.74332524 0.80147654 0.8484021  0.85526449 0.8557702 ]
# 0.8208477151029939
# score: SVC()
# [0.59182848 0.59243528 0.59728964 0.59077577 0.59522605]
# 0.5935110437261443

# %% [markdown]
# We are getting least difference in corss_val and accuracy is in DecisionTreeClassifier

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param={'criterion':['gini','entropy']}
gd_sr=GridSearchCV(estimator=dtc,
                 param_grid=grid_param,
                 scoring='accuracy',cv=5)
gd_sr.fit(x_train,y_train)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'criterion': 'entropy'}
# 0.8184419523744696

# %%
dtc=DecisionTreeClassifier(criterion='entropy')
dtc.fit(x1,y1)
dtc.score(x1,y1)
# Out:
# 0.9998771498771499

# %%
grid_params_={'n_neighbors':np.arange(1,12,2),
             'weights':['uniform','distance']}
gscv=GridSearchCV(knn,grid_params_,cv=5)
gscv.fit(x1,y1)

best_parameters=gscv.best_params_
print(best_parameters)
# Out:
# {'n_neighbors': 11, 'weights': 'uniform'}

# %%
knn=KNeighborsClassifier(weights='distance')
knn.fit(x1,y1)
knn.score(x1,y1)
# Out:
# 0.9998771498771499

# %% [raw]
# parameters={'kernel':['linear','rbf'],'C':[1,10]}
# clf = GridSearchCV(svc,parameters)
# clf.fit(x1,y1)
# clf
#
# print(clf.best_params_)

# %% [raw]
# svc=SVC(kernel='linear',C=1)
# svc.fit(x1,y1)
# t=svc.score(x1,y1)
# print(round(t,2))

# %% [markdown]
# Now we are using best parameter in our model

# %%
dtc=DecisionTreeClassifier(criterion='entropy')
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print('accuracy_score:',)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy_score:
# 0.8202535059331176
# [[5971 1438]
#  [1228 6195]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      7409
#            1       0.81      0.83      0.82      7423
#
#     accuracy                           0.82     14832
#    macro avg       0.82      0.82      0.82     14832
# weighted avg       0.82      0.82      0.82     14832

# %% [markdown]
# So we are getting best accuracy with DecisionTreeClassifier so this is our best model

# %% [markdown]
# # Saving the best model

# %%
import joblib

joblib.dump(dtc,'dtcfile.obj')

dtc_from_joblib=joblib.load('dtcfile.obj')
