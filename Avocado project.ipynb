# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv('avocado.csv')
ds
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# till here we have imported the dataset.

# %% [markdown]
# we can see that their are 18249 rows and 14 columns.

# %% [markdown]
# # EXploratory Data Analysis

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.AveragePrice.value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.05      1
# 3.03      1
# 2.91      1
# 0.48      1
# 2.96      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
df.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %% [markdown]
# we can see that the AveragePrice column is our dependent variable and is continous in nature,thus it is a linear regression problem.

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Thus we can see taht no null values are present in our dataset.

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [raw]
# key observations:
#
# 1 tThe difference in mean and median is not similar in all the columns.
#
# 2 we can see a huge difference in 75% percentile and max in many columns:
#
#    --> we  can see the huge difference in max and 75% in Xlarge Bags,smallbags
# and unnamed:0 column, which shows that  outliers are present.
#
#     -->we can see the small difference in some columns like total volumne,4046,4225and total bags.

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# So we are using Boxplot

# %%
df['Unnamed: 0'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can see that we have no outliers in the column.

# %%
df['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# So in volume column we can see the extreme outliers are present.

# %%
df['4046'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here in  this column we can also see that extreme outliers are present.

# %%
df['4225'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here in this column we can see the outliers.

# %%
df['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can also see the outliers present in our dataset.

# %%
df['Small Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here in this column we can also see the outliers are present.

# %%
df['Large Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# here  in this column we can also see the extreme outliers are present.

# %%
df['year'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that we have no outliers.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Now we are plotting scatter plots to see the relation of each column with the target column.

# %%
sns.scatterplot(data=df,x='Unnamed: 0',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='AveragePrice'>

# %% [markdown]
# here we can see that we have not a linear relation , the price is icreasing and decreasing with unnamed :0.

# %%
sns.scatterplot(data=df,x='Date',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %% [markdown]
# Here we can see that with the increase in date prices both increases and decreases.

# %%
sns.scatterplot(data=df,x='Total Volume',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %% [markdown]
# So here we can see that the price increses for a definite range after that the price decreases with increases in volume we can also see th extreme outliers are present.

# %%
sns.scatterplot(data=df,x='4046',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='4046', ylabel='AveragePrice'>

# %% [markdown]
# So here we can also see that the price increses for a definite range after that the price decreases with increases in volume we can also see the extreme outliers are present.

# %%
sns.scatterplot(data=df,x='4225',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='4225', ylabel='AveragePrice'>

# %% [markdown]
# So here we can also see that the price increses for a definite range after that the price decreases with increases in volume we can also see the extreme outliers are present.

# %%
sns.scatterplot(data=df,x='4770',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='4770', ylabel='AveragePrice'>

# %% [markdown]
# Here we can see that prices decreses with increse in 4770.we can also see the ecxtreme outliers present in it.

# %%
sns.scatterplot(data=df,x='Total Bags',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='AveragePrice'>

# %% [markdown]
#  here we can also see that the price increses for a definite range after that the price decreases with increases in volume we can also see the extreme outliers are present.

# %%
sns.scatterplot(data=df,x='Small Bags',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='AveragePrice'>

# %% [markdown]
# here we can also see that the price increses for a definite range after that the price decreases with increases in volume we can also see the extreme outliers are present.

# %%
sns.scatterplot(data=df,x='Large Bags',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='AveragePrice'>

# %% [markdown]
# here we can also see that the price increses for a definite range after that the price decreases with increases in volume we can also see the extreme outliers are present.

# %% [markdown]
# sns.scatterplot(data=df,x='XLarge Bags',y='AveragePrice')

# %% [markdown]
# here also we are looking the same relation as we have seen in above plots .their are extreme outliers ,prices decrases with increses in XLarge bags

# %%
sns.scatterplot(data=df,x='type',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# Here we can see we have two type and prices for conventional  and organic.prices for organic increaes more.

# %%
sns.scatterplot(data=df,x='year',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# Here we can see that prices increases for different years differently for some year price increases, for some decreses.

# %%
sns.scatterplot(data=df,x='region',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %% [markdown]
# Here we can see the price in each region of the country.

# %% [markdown]
# From the scatter plot we have seen  the relation of each column with target column and noted the information we get.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# From the above plot we have seen the rrelation of each column with other columns in the dataset.

# %%
dfcor=df.corr()
dfcor
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure (figsize=(20,14))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# Observations:
#
# Dark shades are highly negatively correlated.
#
# Almost all the columns are highly negatively correlated with averagePrice column.
# all the columns have very negative correlation. with the target column.

# %% [markdown]
# # To check skewness

# %%
sns.distplot(df['Unnamed: 0'])
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Density'>

# %% [markdown]
# Here we can see the skewness the curve is not normally distributed.

# %%
sns.distplot(df['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness the curve is skewwed from the right.

# %%
sns.distplot(df['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %% [markdown]
# Here also we can see the skewness the curve is skewwed from the right.

# %%
sns.distplot(df['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %% [markdown]
# Here in this column we can see the skewness the curve is skewwed from the right.

# %%
sns.distplot(df['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %% [markdown]
# Here in this column we can see the skewness the curve is skewwed from the right.

# %%
sns.distplot(df['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %% [markdown]
# here also we can see that curve is skewwed from the right.

# %%
sns.distplot(df['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %% [markdown]
# here also we can see that curve is skewwed from the right.

# %%
sns.distplot(df['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %% [markdown]
# here also we can see that curve is skewwed from the right.

# %%
sns.distplot(df['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %% [markdown]
# here also we can see that curve is skewwed from the right.

# %%
sns.distplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %% [markdown]
# Here we can see that 3 curves are normally distributed but 4th is not.

# %% [markdown]
# # Data Cleaning

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['Date']=le.fit_transform(df['Date'])

# %%
df['type']=le.fit_transform(df['type'])

# %%
df['region']=le.fit_transform(df['region'])

# %%
df['Date']
# Out:
# 0         51
# 1         50
# 2         49
# 3         48
# 4         47
#         ...
# 18244    161
# 18245    160
# 18246    159
# 18247    158
# 18248    157
# Name: Date, Length: 18249, dtype: int32

# %%
df['type']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 18244    1
# 18245    1
# 18246    1
# 18247    1
# 18248    1
# Name: type, Length: 18249, dtype: int32

# %%
df['region']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 18244    53
# 18245    53
# 18246    53
# 18247    53
# 18248    53
# Name: region, Length: 18249, dtype: int32

# %% [markdown]
# so we can see that all columns are converted in integer format.

# %%
df
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume     4046       4225  \
# 0               0    51          1.33      64236.62  1036.74   54454.85
# 1               1    50          1.35      54876.98   674.28   44638.81
# 2               2    49          0.93     118220.22   794.70  109149.67
# 3               3    48          1.08      78992.15  1132.00   71976.41
# 4               4    47          1.28      51039.60   941.48   43838.39
# ...           ...   ...           ...           ...      ...        ...
# 18244           7   161          1.63      17074.83  2046.96    1529.20
# 18245           8   160          1.71      13888.04  1191.70    3431.50
# 18246           9   159          1.87      13766.76  1191.92    2452.79
# 18247          10   158          1.93      16205.22  1527.63    2981.04
# 18248          11   157          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  \
# ...

# %% [markdown]
# here we can also see that whole dataset is present in integer format.

# %% [markdown]
# WE are losing high data while removing the outlier .so we are not going to implement any method to remove outlier.

# %% [markdown]
#  Removing skewness

# %% [markdown]
# # Separating independent variable and target variable.

# %%
x1=df.drop('AveragePrice',axis=1)
y1=df['AveragePrice']

# %%
x1.skew()
# Out:
# Unnamed: 0       0.108334
# Date             0.000117
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x1)
df_new=pd.DataFrame(df_new,columns=x1.columns)

# %%
df_new.skew()
# Out:
# Unnamed: 0     -0.242585
# Date           -0.277806
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.213156
# region         -0.261443
# dtype: float64

# %% [markdown]
# Skewness has been removed

# %%
df_new.head()
# Out:
#    Unnamed: 0      Date  Total Volume      4046      4225      4770  \
# 0   -1.968845 -0.583054     -0.086605 -0.658619  0.307313 -0.247250
# 1   -1.792619 -0.605325     -0.155746 -0.776870  0.231647 -0.201041
# 2   -1.648366 -0.627722      0.179327 -0.731947  0.579503 -0.007072
# 3   -1.521609 -0.650247      0.003876 -0.634200  0.415100 -0.148322
# 4   -1.406451 -0.672903     -0.187640 -0.685293  0.224806 -0.137918
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags      type      year  \
# 0   -0.524004   -0.340627   -0.773351    -0.699849 -0.999836 -1.221895
# 1   -0.485890   -0.306425   -0.763435    -0.699849 -0.999836 -1.221895
# 2   -0.552018   -0.366303   -0.750820    -0.699849 -0.999836 -1.221895
# 3   -0.695449   -0.496853   -0.691865    -0.699849 -0.999836 -1.221895
# 4   -0.669157   -0.477201   -0.600975    -0.699849 -0.999836 -1.221895
#
#      region
# 0 -2.011552
# 1 -2.011552
# 2 -2.011552
# 3 -2.011552
# 4 -2.011552

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Creating train test split

# %%
x=df_new
x.shape
# Out:
# (18249, 13)

# %%
y=y1
y.shape
# Out:
# (18249,)

# %%
y=y.reshape(-1,1)

# %%
y.shape
# Out:
# (18249, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=52)

# %%
x_train.shape
# Out:
# (12774, 13)

# %%
x_test.shape
# Out:
# (5475, 13)

# %%
y_train.shape
# Out:
# (12774, 1)

# %%
y_test.shape
# Out:
# (5475, 1)

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Finding Best  Algorithm using multiple models.

# %%
lm=LinearRegression()
dtr=DecisionTreeRegressor()
svr=SVR()
knr=KNeighborsRegressor()
ls=Lasso(alpha=0.0001)
rd=Ridge(alpha=0.0001)

# %%
model=[lm,dtr,svr,knr,ls,rd]

for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('error:',m)
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Mean squared error:',mean_squared_error(y_test,pred))
    print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error: LinearRegression()
# Mean absolute error: 0.20793172530202028
# Mean squared error: 0.07086870220661616
# Root Mean squared error: 0.2662117619614433
# error: DecisionTreeRegressor()
# Mean absolute error: 0.12090228310502284
# Mean squared error: 0.03529662100456621
# Root Mean squared error: 0.18787394977634927
# error: SVR()
# Mean absolute error: 0.13140256101630945
# Mean squared error: 0.03185297812021633
# Root Mean squared error: 0.17847402645823937
# error: KNeighborsRegressor()
# Mean absolute error: 0.09979762557077626
# Mean squared error: 0.020281753424657534
# Root Mean squared error: 0.1424140211659566
# error: Lasso(alpha=0.0001)
# Mean absolute error: 0.20788509156674917
# Mean squared error: 0.07086556662078652
# Root Mean squared error: 0.26620587262640644
# error: Ridge(alpha=0.0001)
# Mean absolute error: 0.20793172447483246
# Mean squared error: 0.07086870199899588
# Root Mean squared error: 0.26621176157149007

# %% [markdown]
# From the above results we can see that the KNeighborsRegressor has minimum error.

# %%
# Let's check the r2_score for all the models

# %%
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('score:',m)
    print(r2_score(y_test,pred))
# Out:
# score: LinearRegression()
# 0.5586506338415116
# score: DecisionTreeRegressor()
# 0.7792821748965066
# score: SVR()
# 0.8016290511059307
# score: KNeighborsRegressor()
# 0.8736912241957258
# score: Lasso(alpha=0.0001)
# 0.5586701613448433
# score: Ridge(alpha=0.0001)
# 0.5586506351345095

# %% [markdown]
# From the above results we can see that the KNeighborsRegressor has maximum r2_score.

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('score:',m)
    print(score)
    print(score.mean())
# Out:
# score: LinearRegression()
# [-0.25632874  0.22718823  0.50076094  0.18869564  0.26527499]
# 0.18511821089339464
# score: DecisionTreeRegressor()
# [-0.50068402  0.06658912  0.31389265 -0.45577398 -0.33384579]
# -0.18196440292906785
# score: SVR()
# [-0.25349164  0.38815469  0.37246668  0.29007911  0.12225625]
# 0.18389301984060807
# score: KNeighborsRegressor()
# [-0.43894891  0.24423537  0.49823208  0.00257824 -0.06749706]
# 0.047719945946655004
# score: Lasso(alpha=0.0001)
# [-0.24919138  0.22695378  0.49999633  0.19090856  0.26356371]
# 0.18644619984158045
# score: Ridge(alpha=0.0001)
# [-0.25632865  0.22718822  0.50076094  0.18869569  0.26527497]
# 0.18511823432056676

# %% [raw]
# from cross validation score we can see that Lasso regression has least crros_val_score.
# thus this is our best model.

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
dtr=DecisionTreeRegressor()
grid_param={'criterion':['mse','mae','friedman_mse','poisson']}
gd_sr=GridSearchCV(estimator=dtr,
                   scoring='accuracy',
                   param_grid=grid_param,
                   cv=5)
gd_sr.fit(x_train,y_train)
best_parameters=gd_sr.best_params_
print(best_parameters)
# Out:
# {'criterion': 'mse'}

# %%
dtr=DecisionTreeRegressor(criterion='mse')
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
param={'n_neighbors':np.arange(1,12,2),
      'weights':['uniform','distance']}
knr=KNeighborsRegressor()
gscv=GridSearchCV(knr,param,cv=5)
gscv.fit(x_train,y_train)

best_parameters=gscv.best_params_
print(best_parameters)
# Out:
# {'n_neighbors': 3, 'weights': 'distance'}

# %%
knr=KNeighborsRegressor(weights='distance')
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# By using these parameters we are not getting that much score.So we are not using them.

# %% [markdown]
# # Saving our Best Model

# %%
import joblib
joblib.dump(ls, 'lsfile.obj')
ls_from_joblib=joblib.load('lsfile.obj')
